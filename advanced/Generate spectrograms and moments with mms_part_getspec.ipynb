# %% [markdown]
# This notebook shows how to use `mms_part_getspec` to generate particle spectrograms and moments from level 2 MMS FPI and HPCA velocity distribution data.
#
# Get started by importing `mms_part_getspec`

# %%
from pyspedas.mms.particles.mms_part_getspec import mms_part_getspec
from pytplot import tplot

# %% [markdown]
# ### FPI spectrograms and moments
#
# Notes:
# - as with the load routines, most keywords have defaults, e.g., the instrument keyword defaults to 'fpi'
# - internal and external photoelectron corrections are applied to FPI electrons prior to generating the moments

# %%
mms_part_getspec(trange=['2015-10-16/13:05:40', '2015-10-16/13:06:10'], 
                 instrument='fpi',
                 data_rate='brst', 
                 probe=1, 
                 species='e', 
                 output=['phi', 'theta', 'energy', 'pa', 'gyro', 'moments'])
# Out:
# 30-Jul-21 12:43:37: Downloading mms1_fpi_brst_l2_des-dist_20151016130524_v3.3.0.cdf to pydata\mms1\fpi\brst\l2\des-dist\2015\10\16
# Time clip was applied to: mms1_des_errorflags_brst
# Time clip was applied to: mms1_des_compressionloss_brst
# Time clip was applied to: mms1_des_steptable_parity_brst
# Time clip was applied to: mms1_des_startdelphi_count_brst
# Time clip was applied to: mms1_des_startdelphi_angle_brst
# Time clip was applied to: mms1_des_dist_brst
# Time clip was applied to: mms1_des_disterr_brst
# Time clip was applied to: mms1_des_sector_despinp_brst
# That name is currently not in pytplot
# That name is currently not in pytplot
# That name is currently not in pytplot
# Loaded variables:
# mms1_des_errorflags_brst
# mms1_des_compressionloss_brst
# mms1_des_steptable_parity_brst
# mms1_des_startdelphi_count_brst
# mms1_des_startdelphi_angle_brst
# mms1_des_dist_brst
# mms1_des_disterr_brst
# mms1_des_sector_despinp_brst
# 30-Jul-21 12:44:18: Downloading mms1_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf to pydata\mms1\mec\srvy\l2\ephts04d\2015\10
# Time clip was applied to: mms1_mec_dipole_tilt
# Time clip was applied to: mms1_mec_gmst
# Time clip was applied to: mms1_mec_mlat
# Time clip was applied to: mms1_mec_mlt
# Time clip was applied to: mms1_mec_l_dipole
# Time clip was applied to: mms1_mec_quat_eci_to_bcs
# Time clip was applied to: mms1_mec_quat_eci_to_dbcs
# Time clip was applied to: mms1_mec_quat_eci_to_dmpa
# Time clip was applied to: mms1_mec_quat_eci_to_smpa
# Time clip was applied to: mms1_mec_quat_eci_to_dsl
# Time clip was applied to: mms1_mec_quat_eci_to_ssl
# Time clip was applied to: mms1_mec_L_vec
# Time clip was applied to: mms1_mec_Z_vec
# Time clip was applied to: mms1_mec_P_vec
# Time clip was applied to: mms1_mec_L_phase
# Time clip was applied to: mms1_mec_Z_phase
# Time clip was applied to: mms1_mec_P_phase
# Time clip was applied to: mms1_mec_kp
# Time clip was applied to: mms1_mec_dst
# Time clip was applied to: mms1_mec_earth_eclipse_flag
# Time clip was applied to: mms1_mec_moon_eclipse_flag
# Time clip was applied to: mms1_mec_r_eci
# Time clip was applied to: mms1_mec_v_eci
# Time clip was applied to: mms1_mec_r_gsm
# Time clip was applied to: mms1_mec_v_gsm
# Time clip was applied to: mms1_mec_quat_eci_to_gsm
# Time clip was applied to: mms1_mec_r_geo
# Time clip was applied to: mms1_mec_v_geo
# Time clip was applied to: mms1_mec_quat_eci_to_geo
# Time clip was applied to: mms1_mec_r_sm
# Time clip was applied to: mms1_mec_v_sm
# Time clip was applied to: mms1_mec_quat_eci_to_sm
# Time clip was applied to: mms1_mec_r_gse
# Time clip was applied to: mms1_mec_v_gse
# Time clip was applied to: mms1_mec_quat_eci_to_gse
# Time clip was applied to: mms1_mec_r_gse2000
# Time clip was applied to: mms1_mec_v_gse2000
# Time clip was applied to: mms1_mec_quat_eci_to_gse2000
# Time clip was applied to: mms1_mec_geod_lat
# Time clip was applied to: mms1_mec_geod_lon
# Time clip was applied to: mms1_mec_geod_height
# Time clip was applied to: mms1_mec_r_sun_de421_eci
# Time clip was applied to: mms1_mec_r_moon_de421_eci
# Time clip was applied to: mms1_mec_fieldline_type
# Time clip was applied to: mms1_mec_bsc_gsm
# Time clip was applied to: mms1_mec_loss_cone_angle_s
# Time clip was applied to: mms1_mec_loss_cone_angle_n
# Time clip was applied to: mms1_mec_pfs_geod_latlon
# Time clip was applied to: mms1_mec_pfn_geod_latlon
# Time clip was applied to: mms1_mec_pfs_gsm
# Time clip was applied to: mms1_mec_bfs_gsm
# Time clip was applied to: mms1_mec_pfn_gsm
# Time clip was applied to: mms1_mec_bfn_gsm
# Time clip was applied to: mms1_mec_pmin_gsm
# Time clip was applied to: mms1_mec_bmin_gsm
# Loaded variables:
# mms1_mec_dipole_tilt
# mms1_mec_gmst
# mms1_mec_mlat
# mms1_mec_mlt
# mms1_mec_l_dipole
# mms1_mec_quat_eci_to_bcs
# mms1_mec_quat_eci_to_dbcs
# mms1_mec_quat_eci_to_dmpa
# mms1_mec_quat_eci_to_smpa
# mms1_mec_quat_eci_to_dsl
# mms1_mec_quat_eci_to_ssl
# mms1_mec_L_vec
# mms1_mec_Z_vec
# mms1_mec_P_vec
# mms1_mec_L_phase
# mms1_mec_Z_phase
# mms1_mec_P_phase
# mms1_mec_kp
# mms1_mec_dst
# mms1_mec_earth_eclipse_flag
# mms1_mec_moon_eclipse_flag
# mms1_mec_r_eci
# mms1_mec_v_eci
# mms1_mec_r_gsm
# mms1_mec_v_gsm
# mms1_mec_quat_eci_to_gsm
# mms1_mec_r_geo
# mms1_mec_v_geo
# mms1_mec_quat_eci_to_geo
# mms1_mec_r_sm
# mms1_mec_v_sm
# mms1_mec_quat_eci_to_sm
# mms1_mec_r_gse
# mms1_mec_v_gse
# mms1_mec_quat_eci_to_gse
# mms1_mec_r_gse2000
# mms1_mec_v_gse2000
# mms1_mec_quat_eci_to_gse2000
# mms1_mec_geod_lat
# mms1_mec_geod_lon
# mms1_mec_geod_height
# mms1_mec_r_sun_de421_eci
# mms1_mec_r_moon_de421_eci
# mms1_mec_fieldline_type
# mms1_mec_bsc_gsm
# mms1_mec_loss_cone_angle_s
# mms1_mec_loss_cone_angle_n
# mms1_mec_pfs_geod_latlon
# mms1_mec_pfn_geod_latlon
# mms1_mec_pfs_gsm
# mms1_mec_bfs_gsm
# mms1_mec_pfn_gsm
# mms1_mec_bfn_gsm
# mms1_mec_pmin_gsm
# mms1_mec_bmin_gsm
# 30-Jul-21 12:44:31: Downloading mms1_fgm_brst_l2_20151016130334_v4.18.1.cdf to pydata\mms1\fgm\brst\l2\2015\10\16
# 30-Jul-21 12:44:32: Downloading mms1_fgm_brst_l2_20151016130524_v4.18.1.cdf to pydata\mms1\fgm\brst\l2\2015\10\16
# The lengths of x and y do not match!
# mms1_fgm_rdeltahalf_brst_l2 is currently not in pytplot.
# Time clip was applied to: mms1_fgm_b_gse_brst_l2
# Time clip was applied to: mms1_fgm_b_gsm_brst_l2
# Time clip was applied to: mms1_fgm_b_dmpa_brst_l2
# Time clip was applied to: mms1_fgm_b_bcs_brst_l2
# Time clip was applied to: mms1_fgm_flag_brst_l2
# Time clip was applied to: mms1_fgm_r_gse_brst_l2
# Time clip was applied to: mms1_fgm_r_gsm_brst_l2
# Time clip was applied to: mms1_fgm_hirange_brst_l2
# Time clip was applied to: mms1_fgm_bdeltahalf_brst_l2
# Time clip was applied to: mms1_fgm_stemp_brst_l2
# Time clip was applied to: mms1_fgm_etemp_brst_l2
# Time clip was applied to: mms1_fgm_mode_brst_l2
# Time clip error: No pytplot names were provided.
# That name is currently not in pytplot
# That name is currently not in pytplot
# Loaded variables:
# Epoch
# mms1_fgm_b_gse_brst_l2
# mms1_fgm_b_gsm_brst_l2
# mms1_fgm_b_dmpa_brst_l2
# mms1_fgm_b_bcs_brst_l2
# mms1_fgm_flag_brst_l2
# Epoch_state
# mms1_fgm_hirange_brst_l2
# mms1_fgm_bdeltahalf_brst_l2
# mms1_fgm_stemp_brst_l2
# mms1_fgm_etemp_brst_l2
# mms1_fgm_mode_brst_l2
# mms1_fgm_rdeltahalf_brst_l2
# mms1_fgm_b_dmpa_brst_l2_bvec
# mms1_fgm_b_dmpa_brst_l2_btot
# mms1_fgm_b_gse_brst_l2_bvec
# mms1_fgm_b_gse_brst_l2_btot
# mms1_fgm_b_gsm_brst_l2_bvec
# mms1_fgm_b_gsm_brst_l2_btot
# mms1_fgm_b_bcs_brst_l2_bvec
# mms1_fgm_b_bcs_brst_l2_btot
# 30-Jul-21 12:44:37: Downloading mms1_edp_brst_l2_scpot_20151016130334_v2.4.0.cdf to pydata\mms1\edp\brst\l2\scpot\2015\10\16
# 30-Jul-21 12:44:53: Downloading mms1_edp_brst_l2_scpot_20151016130524_v2.4.0.cdf to pydata\mms1\edp\brst\l2\scpot\2015\10\16
# Time clip was applied to: mms1_edp_scpot_brst_l2
# Loaded variables:
# mms1_edp_scpot_brst_l2
# ['gse', 'gei']
# Running transformation: subgse2gei
# Output variable: mms1_mec_r_gse
# tinterpol (linear) was applied to: mms1_fgm_b_gse_brst_l2_bvec_pgs_temp
# tinterpol (linear) was applied to: mms1_mec_r_gse_pgs_temp
# ['gei', 'gse']
# Running transformation: subgei2gse
# Output variable: mms1_mec_r_gse_pgs_temp
# 30-Jul-21 12:45:04: Downloading remote index: https://lasp.colorado.edu/mms/sdc/public/data/models/fpi/
# tinterpol (linear) was applied to: mms1_fgm_b_gse_brst_l2_bvec_pgs_temp
# tinterpol (linear) was applied to: mms1_edp_scpot_brst_l2_pgs_temp
# 30-Jul-21 12:45:04: Downloading https://lasp.colorado.edu/mms/sdc/public/data/models/fpi/mms_fpi_brst_l2_des-bgdist_v1.1.0_p0-2.cdf to pydata\mms\sdc\public\data\models\fpi\mms_fpi_brst_l2_des-bgdist_v1.1.0_p0-2.cdf
# 30-Jul-21 12:45:15: Download complete: pydata\mms\sdc\public\data\models\fpi\mms_fpi_brst_l2_des-bgdist_v1.1.0_p0-2.cdf
# 30-Jul-21 12:45:18: c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\pyspedas\particles\moments\moments_3d.py:50: RuntimeWarning: divide by zero encountered in true_divide
#   weight = (energy + charge*sc_pot)/de + 0.5
#
# 30-Jul-21 12:45:28: mms1_des_dist_brst is 3% done.
# 30-Jul-21 12:45:38: mms1_des_dist_brst is 6% done.
# 30-Jul-21 12:45:49: mms1_des_dist_brst is 8% done.
# 30-Jul-21 12:45:59: mms1_des_dist_brst is 10% done.
# 30-Jul-21 12:46:09: mms1_des_dist_brst is 13% done.
# 30-Jul-21 12:46:19: mms1_des_dist_brst is 15% done.
# 30-Jul-21 12:46:29: mms1_des_dist_brst is 18% done.
# 30-Jul-21 12:46:40: mms1_des_dist_brst is 20% done.
# 30-Jul-21 12:46:50: mms1_des_dist_brst is 23% done.
# 30-Jul-21 12:47:00: mms1_des_dist_brst is 25% done.
# 30-Jul-21 12:47:10: mms1_des_dist_brst is 27% done.
# 30-Jul-21 12:47:21: mms1_des_dist_brst is 30% done.
# 30-Jul-21 12:47:31: mms1_des_dist_brst is 32% done.
# 30-Jul-21 12:47:41: mms1_des_dist_brst is 35% done.
# 30-Jul-21 12:47:52: mms1_des_dist_brst is 37% done.
# 30-Jul-21 12:48:02: mms1_des_dist_brst is 40% done.
# 30-Jul-21 12:48:12: mms1_des_dist_brst is 42% done.
# 30-Jul-21 12:48:22: mms1_des_dist_brst is 44% done.
# 30-Jul-21 12:48:32: mms1_des_dist_brst is 47% done.
# 30-Jul-21 12:48:42: mms1_des_dist_brst is 49% done.
# 30-Jul-21 12:48:53: mms1_des_dist_brst is 52% done.
# 30-Jul-21 12:49:03: mms1_des_dist_brst is 54% done.
# 30-Jul-21 12:49:13: mms1_des_dist_brst is 57% done.
# 30-Jul-21 12:49:23: mms1_des_dist_brst is 60% done.
# 30-Jul-21 12:49:33: mms1_des_dist_brst is 62% done.
# 30-Jul-21 12:49:43: mms1_des_dist_brst is 65% done.
# 30-Jul-21 12:49:54: mms1_des_dist_brst is 67% done.
# 30-Jul-21 12:50:04: mms1_des_dist_brst is 70% done.
# 30-Jul-21 12:50:14: mms1_des_dist_brst is 72% done.
# 30-Jul-21 12:50:24: mms1_des_dist_brst is 75% done.
# 30-Jul-21 12:50:35: mms1_des_dist_brst is 77% done.
# 30-Jul-21 12:50:45: mms1_des_dist_brst is 80% done.
# 30-Jul-21 12:50:55: mms1_des_dist_brst is 82% done.
# 30-Jul-21 12:51:05: mms1_des_dist_brst is 85% done.
# 30-Jul-21 12:51:15: mms1_des_dist_brst is 87% done.
# 30-Jul-21 12:51:25: mms1_des_dist_brst is 90% done.
# 30-Jul-21 12:51:35: mms1_des_dist_brst is 92% done.
# 30-Jul-21 12:51:46: mms1_des_dist_brst is 95% done.
# 30-Jul-21 12:51:56: mms1_des_dist_brst is 97% done.
# 30-Jul-21 12:52:06: mms1_des_dist_brst is 100% done.
# 30-Jul-21 12:52:07: Finished; time to run: 510.4 seconds.
# ['mms1_des_dist_brst_density',
#  'mms1_des_dist_brst_flux',
#  'mms1_des_dist_brst_mftens',
#  'mms1_des_dist_brst_velocity',
#  'mms1_des_dist_brst_ptens',
#  'mms1_des_dist_brst_vthermal',
#  'mms1_des_dist_brst_avgtemp',
#  'mms1_des_dist_brst_energy',
#  'mms1_des_dist_brst_theta',
#  'mms1_des_dist_brst_phi',
#  'mms1_des_dist_brst_pa',
#  'mms1_des_dist_brst_gyro']

# %%
tplot(['mms1_des_dist_brst_energy', 'mms1_des_dist_brst_density'])

# %% [markdown]
# ### HPCA spectrograms and moments

# %%
mms_part_getspec(trange=['2019-10-16', '2019-10-17'], 
                 instrument='hpca',
                 probe=1, 
                 species='hplus', 
                 output=['phi', 'theta', 'energy', 'pa', 'gyro', 'moments'])
# Out:
# 30-Jul-21 15:44:51: Downloading mms1_hpca_srvy_l2_ion_20191016000000_v4.1.4.cdf to pydata\mms1\hpca\srvy\l2\ion\2019\10
# 30-Jul-21 15:45:40: Downloading mms1_hpca_srvy_l2_ion_20191016060000_v4.1.4.cdf to pydata\mms1\hpca\srvy\l2\ion\2019\10
# 30-Jul-21 15:46:11: Downloading mms1_hpca_srvy_l2_ion_20191016120000_v4.1.3.cdf to pydata\mms1\hpca\srvy\l2\ion\2019\10
# 30-Jul-21 15:46:41: Downloading mms1_hpca_srvy_l2_ion_20191016180000_v4.1.3.cdf to pydata\mms1\hpca\srvy\l2\ion\2019\10
# 30-Jul-21 15:46:56: c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\pytplot\importers\cdf_to_tplot.py:197: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   delta_plus_var = delta_plus_var.astype(float)*np.float(si_conv.split('>')[0])
#
# 30-Jul-21 15:46:56: c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\pytplot\importers\cdf_to_tplot.py:209: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   delta_minus_var = delta_minus_var.astype(float)*np.float(si_conv.split('>')[0])
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Loaded variables:
# Epoch
# Epoch_MINUS
# Epoch_PLUS
# mms1_hpca_polar_anode_number
# mms1_hpca_azimuth_decimation_factor
# mms1_hpca_polar_decimation_factor
# mms1_hpca_energy_decimation_factor
# mms1_hpca_sweep_table_number
# mms1_hpca_start_azimuth
# mms1_hpca_science_mode
# mms1_hpca_ion_energy
# mms1_hpca_hplus_flux
# mms1_hpca_hplus_phase_space_density
# mms1_hpca_heplus_flux
# mms1_hpca_heplus_phase_space_density
# mms1_hpca_heplusplus_flux
# mms1_hpca_heplusplus_phase_space_density
# mms1_hpca_oplus_flux
# mms1_hpca_oplus_phase_space_density
# mms1_hpca_B_GSE_sweep_avg
# mms1_hpca_B_GSM_sweep_avg
# Epoch_Angles
# Epoch_MINUS_Angles
# Epoch_PLUS_Angles
# mms1_hpca_azimuth_angles_degrees
# mms1_hpca_azimuth_angles_per_ev_degrees
# mms1_hpca_centroid_elevation_angle
# mms1_hpca_azimuth_index
# mms1_hpca_energy_step_number
# mms1_hpca_MCP_VMON_MIN_converted
# mms1_hpca_TOF_VMON_MIN_converted
# mms1_hpca_decimation_factor_index
# mms1_hpca_acquisition_time
# 30-Jul-21 15:48:44: Downloading mms1_mec_srvy_l2_ephts04d_20191015_v2.2.1.cdf to pydata\mms1\mec\srvy\l2\ephts04d\2019\10
# 30-Jul-21 15:48:45: Downloading mms1_mec_srvy_l2_ephts04d_20191016_v2.2.1.cdf to pydata\mms1\mec\srvy\l2\ephts04d\2019\10
# 30-Jul-21 15:48:45: Downloading mms1_mec_srvy_l2_ephts04d_20191017_v2.2.1.cdf to pydata\mms1\mec\srvy\l2\ephts04d\2019\10
# Time clip was applied to: mms1_mec_dipole_tilt
# Time clip was applied to: mms1_mec_gmst
# Time clip was applied to: mms1_mec_mlat
# Time clip was applied to: mms1_mec_mlt
# Time clip was applied to: mms1_mec_l_dipole
# Time clip was applied to: mms1_mec_quat_eci_to_bcs
# Time clip was applied to: mms1_mec_quat_eci_to_dbcs
# Time clip was applied to: mms1_mec_quat_eci_to_dmpa
# Time clip was applied to: mms1_mec_quat_eci_to_smpa
# Time clip was applied to: mms1_mec_quat_eci_to_dsl
# Time clip was applied to: mms1_mec_quat_eci_to_ssl
# Time clip was applied to: mms1_mec_L_vec
# Time clip was applied to: mms1_mec_Z_vec
# Time clip was applied to: mms1_mec_P_vec
# Time clip was applied to: mms1_mec_L_phase
# Time clip was applied to: mms1_mec_Z_phase
# Time clip was applied to: mms1_mec_P_phase
# Time clip was applied to: mms1_mec_kp
# Time clip was applied to: mms1_mec_dst
# Time clip was applied to: mms1_mec_earth_eclipse_flag
# Time clip was applied to: mms1_mec_moon_eclipse_flag
# Time clip was applied to: mms1_mec_r_eci
# Time clip was applied to: mms1_mec_v_eci
# Time clip was applied to: mms1_mec_r_gsm
# Time clip was applied to: mms1_mec_v_gsm
# Time clip was applied to: mms1_mec_quat_eci_to_gsm
# Time clip was applied to: mms1_mec_r_geo
# Time clip was applied to: mms1_mec_v_geo
# Time clip was applied to: mms1_mec_quat_eci_to_geo
# Time clip was applied to: mms1_mec_r_sm
# Time clip was applied to: mms1_mec_v_sm
# Time clip was applied to: mms1_mec_quat_eci_to_sm
# Time clip was applied to: mms1_mec_r_gse
# Time clip was applied to: mms1_mec_v_gse
# Time clip was applied to: mms1_mec_quat_eci_to_gse
# Time clip was applied to: mms1_mec_r_gse2000
# Time clip was applied to: mms1_mec_v_gse2000
# Time clip was applied to: mms1_mec_quat_eci_to_gse2000
# Time clip was applied to: mms1_mec_geod_lat
# Time clip was applied to: mms1_mec_geod_lon
# Time clip was applied to: mms1_mec_geod_height
# Time clip was applied to: mms1_mec_r_sun_de421_eci
# Time clip was applied to: mms1_mec_r_moon_de421_eci
# Time clip was applied to: mms1_mec_fieldline_type
# Time clip was applied to: mms1_mec_bsc_gsm
# Time clip was applied to: mms1_mec_loss_cone_angle_s
# Time clip was applied to: mms1_mec_loss_cone_angle_n
# Time clip was applied to: mms1_mec_pfs_geod_latlon
# Time clip was applied to: mms1_mec_pfn_geod_latlon
# Time clip was applied to: mms1_mec_pfs_gsm
# Time clip was applied to: mms1_mec_bfs_gsm
# Time clip was applied to: mms1_mec_pfn_gsm
# Time clip was applied to: mms1_mec_bfn_gsm
# Time clip was applied to: mms1_mec_pmin_gsm
# Time clip was applied to: mms1_mec_bmin_gsm
# Loaded variables:
# mms1_mec_dipole_tilt
# mms1_mec_gmst
# mms1_mec_mlat
# mms1_mec_mlt
# mms1_mec_l_dipole
# mms1_mec_quat_eci_to_bcs
# mms1_mec_quat_eci_to_dbcs
# mms1_mec_quat_eci_to_dmpa
# mms1_mec_quat_eci_to_smpa
# mms1_mec_quat_eci_to_dsl
# mms1_mec_quat_eci_to_ssl
# mms1_mec_L_vec
# mms1_mec_Z_vec
# mms1_mec_P_vec
# mms1_mec_L_phase
# mms1_mec_Z_phase
# mms1_mec_P_phase
# mms1_mec_kp
# mms1_mec_dst
# mms1_mec_earth_eclipse_flag
# mms1_mec_moon_eclipse_flag
# mms1_mec_r_eci
# mms1_mec_v_eci
# mms1_mec_r_gsm
# mms1_mec_v_gsm
# mms1_mec_quat_eci_to_gsm
# mms1_mec_r_geo
# mms1_mec_v_geo
# mms1_mec_quat_eci_to_geo
# mms1_mec_r_sm
# mms1_mec_v_sm
# mms1_mec_quat_eci_to_sm
# mms1_mec_r_gse
# mms1_mec_v_gse
# mms1_mec_quat_eci_to_gse
# mms1_mec_r_gse2000
# mms1_mec_v_gse2000
# mms1_mec_quat_eci_to_gse2000
# mms1_mec_geod_lat
# mms1_mec_geod_lon
# mms1_mec_geod_height
# mms1_mec_r_sun_de421_eci
# mms1_mec_r_moon_de421_eci
# mms1_mec_fieldline_type
# mms1_mec_bsc_gsm
# mms1_mec_loss_cone_angle_s
# mms1_mec_loss_cone_angle_n
# mms1_mec_pfs_geod_latlon
# mms1_mec_pfn_geod_latlon
# mms1_mec_pfs_gsm
# mms1_mec_bfs_gsm
# mms1_mec_pfn_gsm
# mms1_mec_bfn_gsm
# mms1_mec_pmin_gsm
# mms1_mec_bmin_gsm
# 30-Jul-21 15:49:20: Downloading mms1_fgm_srvy_l2_20191015_v5.214.0.cdf to pydata\mms1\fgm\srvy\l2\2019\10
# 30-Jul-21 15:49:36: Downloading mms1_fgm_srvy_l2_20191016_v5.212.0.cdf to pydata\mms1\fgm\srvy\l2\2019\10
# 30-Jul-21 15:49:45: Downloading mms1_fgm_srvy_l2_20191017_v5.212.0.cdf to pydata\mms1\fgm\srvy\l2\2019\10
# Time clip was applied to: mms1_fgm_b_gse_srvy_l2
# Time clip was applied to: mms1_fgm_b_gsm_srvy_l2
# Time clip was applied to: mms1_fgm_b_dmpa_srvy_l2
# Time clip was applied to: mms1_fgm_b_bcs_srvy_l2
# Time clip was applied to: mms1_fgm_flag_srvy_l2
# Time clip was applied to: mms1_fgm_r_gse_srvy_l2
# Time clip was applied to: mms1_fgm_r_gsm_srvy_l2
# Time clip was applied to: mms1_fgm_hirange_srvy_l2
# Time clip was applied to: mms1_fgm_bdeltahalf_srvy_l2
# Time clip was applied to: mms1_fgm_stemp_srvy_l2
# Time clip was applied to: mms1_fgm_etemp_srvy_l2
# Time clip was applied to: mms1_fgm_mode_srvy_l2
# Time clip was applied to: mms1_fgm_rdeltahalf_srvy_l2
# That name is currently not in pytplot
# That name is currently not in pytplot
# Loaded variables:
# Epoch
# mms1_fgm_b_gse_srvy_l2
# mms1_fgm_b_gsm_srvy_l2
# mms1_fgm_b_dmpa_srvy_l2
# mms1_fgm_b_bcs_srvy_l2
# mms1_fgm_flag_srvy_l2
# Epoch_state
# mms1_fgm_hirange_srvy_l2
# mms1_fgm_bdeltahalf_srvy_l2
# mms1_fgm_stemp_srvy_l2
# mms1_fgm_etemp_srvy_l2
# mms1_fgm_mode_srvy_l2
# mms1_fgm_rdeltahalf_srvy_l2
# mms1_fgm_b_dmpa_srvy_l2_bvec
# mms1_fgm_b_dmpa_srvy_l2_btot
# mms1_fgm_b_gse_srvy_l2_bvec
# mms1_fgm_b_gse_srvy_l2_btot
# mms1_fgm_b_gsm_srvy_l2_bvec
# mms1_fgm_b_gsm_srvy_l2_btot
# mms1_fgm_b_bcs_srvy_l2_bvec
# mms1_fgm_b_bcs_srvy_l2_btot
# 30-Jul-21 15:50:43: Downloading mms1_edp_fast_l2_scpot_20191015000000_v2.6.3.cdf to pydata\mms1\edp\fast\l2\scpot\2019\10
# 30-Jul-21 15:51:19: Downloading mms1_edp_fast_l2_scpot_20191016000000_v2.6.2.cdf to pydata\mms1\edp\fast\l2\scpot\2019\10
# 30-Jul-21 15:51:28: Downloading mms1_edp_fast_l2_scpot_20191017000000_v2.6.2.cdf to pydata\mms1\edp\fast\l2\scpot\2019\10
# Time clip was applied to: mms1_edp_scpot_fast_l2
# Loaded variables:
# mms1_edp_scpot_fast_l2
# ['gse', 'gei']
# Running transformation: subgse2gei
# Output variable: mms1_mec_r_gse
# tinterpol (linear) was applied to: mms1_fgm_b_gse_srvy_l2_bvec_pgs_temp
# tinterpol (linear) was applied to: mms1_mec_r_gse_pgs_temp
# ['gei', 'gse']
# Running transformation: subgei2gse
# Output variable: mms1_mec_r_gse_pgs_temp
# tinterpol (linear) was applied to: mms1_fgm_b_gse_srvy_l2_bvec_pgs_temp
# tinterpol (linear) was applied to: mms1_edp_scpot_fast_l2_pgs_temp
# 30-Jul-21 15:51:57: c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\pyspedas\particles\moments\moments_3d.py:50: RuntimeWarning: divide by zero encountered in true_divide
#   weight = (energy + charge*sc_pot)/de + 0.5
#
# 30-Jul-21 15:52:07: mms1_hpca_hplus_phase_space_density is 0% done.
# 30-Jul-21 15:52:18: mms1_hpca_hplus_phase_space_density is 0% done.
# 30-Jul-21 15:52:28: mms1_hpca_hplus_phase_space_density is 0% done.
# 30-Jul-21 15:52:38: mms1_hpca_hplus_phase_space_density is 1% done.
# 30-Jul-21 15:52:49: mms1_hpca_hplus_phase_space_density is 1% done.
# 30-Jul-21 15:52:59: mms1_hpca_hplus_phase_space_density is 1% done.
# 30-Jul-21 15:53:10: mms1_hpca_hplus_phase_space_density is 1% done.
# 30-Jul-21 15:53:20: mms1_hpca_hplus_phase_space_density is 1% done.
# 30-Jul-21 15:53:30: mms1_hpca_hplus_phase_space_density is 1% done.
# 30-Jul-21 15:53:40: mms1_hpca_hplus_phase_space_density is 2% done.
# 30-Jul-21 15:53:51: mms1_hpca_hplus_phase_space_density is 2% done.
# 30-Jul-21 15:54:01: mms1_hpca_hplus_phase_space_density is 2% done.
# 30-Jul-21 15:54:12: mms1_hpca_hplus_phase_space_density is 2% done.
# 30-Jul-21 15:54:22: mms1_hpca_hplus_phase_space_density is 2% done.
# 30-Jul-21 15:54:33: mms1_hpca_hplus_phase_space_density is 2% done.
# 30-Jul-21 15:54:43: mms1_hpca_hplus_phase_space_density is 3% done.
# 30-Jul-21 15:54:53: mms1_hpca_hplus_phase_space_density is 3% done.
# 30-Jul-21 15:55:03: mms1_hpca_hplus_phase_space_density is 3% done.
# 30-Jul-21 15:55:14: mms1_hpca_hplus_phase_space_density is 3% done.
# 30-Jul-21 15:55:24: mms1_hpca_hplus_phase_space_density is 3% done.
# 30-Jul-21 15:55:34: mms1_hpca_hplus_phase_space_density is 3% done.
# 30-Jul-21 15:55:44: mms1_hpca_hplus_phase_space_density is 4% done.
# 30-Jul-21 15:55:54: mms1_hpca_hplus_phase_space_density is 4% done.
# 30-Jul-21 15:56:05: mms1_hpca_hplus_phase_space_density is 4% done.
# 30-Jul-21 15:56:16: mms1_hpca_hplus_phase_space_density is 4% done.
# 30-Jul-21 15:56:26: mms1_hpca_hplus_phase_space_density is 4% done.
# 30-Jul-21 15:56:36: mms1_hpca_hplus_phase_space_density is 4% done.
# 30-Jul-21 15:56:47: mms1_hpca_hplus_phase_space_density is 5% done.
# 30-Jul-21 15:56:57: mms1_hpca_hplus_phase_space_density is 5% done.
# 30-Jul-21 15:57:07: mms1_hpca_hplus_phase_space_density is 5% done.
# 30-Jul-21 15:57:17: mms1_hpca_hplus_phase_space_density is 5% done.
# 30-Jul-21 15:57:28: mms1_hpca_hplus_phase_space_density is 5% done.
# 30-Jul-21 15:57:39: mms1_hpca_hplus_phase_space_density is 6% done.
# 30-Jul-21 15:57:49: mms1_hpca_hplus_phase_space_density is 6% done.
# 30-Jul-21 15:57:59: mms1_hpca_hplus_phase_space_density is 6% done.
# 30-Jul-21 15:58:09: mms1_hpca_hplus_phase_space_density is 6% done.
# 30-Jul-21 15:58:20: mms1_hpca_hplus_phase_space_density is 6% done.
# 30-Jul-21 15:58:31: mms1_hpca_hplus_phase_space_density is 6% done.
# 30-Jul-21 15:58:41: mms1_hpca_hplus_phase_space_density is 7% done.
# 30-Jul-21 15:58:51: mms1_hpca_hplus_phase_space_density is 7% done.
# 30-Jul-21 15:59:02: mms1_hpca_hplus_phase_space_density is 7% done.
# 30-Jul-21 15:59:12: mms1_hpca_hplus_phase_space_density is 7% done.
# 30-Jul-21 15:59:23: mms1_hpca_hplus_phase_space_density is 7% done.
# 30-Jul-21 15:59:33: mms1_hpca_hplus_phase_space_density is 7% done.
# 30-Jul-21 15:59:43: mms1_hpca_hplus_phase_space_density is 8% done.
# 30-Jul-21 15:59:53: mms1_hpca_hplus_phase_space_density is 8% done.
# 30-Jul-21 16:00:04: mms1_hpca_hplus_phase_space_density is 8% done.
# 30-Jul-21 16:00:14: mms1_hpca_hplus_phase_space_density is 8% done.
# 30-Jul-21 16:00:24: mms1_hpca_hplus_phase_space_density is 8% done.
# 30-Jul-21 16:00:34: mms1_hpca_hplus_phase_space_density is 9% done.
# 30-Jul-21 16:00:45: mms1_hpca_hplus_phase_space_density is 9% done.
# 30-Jul-21 16:00:55: mms1_hpca_hplus_phase_space_density is 9% done.
# 30-Jul-21 16:01:05: mms1_hpca_hplus_phase_space_density is 9% done.
# 30-Jul-21 16:01:16: mms1_hpca_hplus_phase_space_density is 9% done.
# 30-Jul-21 16:01:26: mms1_hpca_hplus_phase_space_density is 9% done.
# 30-Jul-21 16:01:37: mms1_hpca_hplus_phase_space_density is 10% done.
# 30-Jul-21 16:01:47: mms1_hpca_hplus_phase_space_density is 10% done.
# 30-Jul-21 16:01:58: mms1_hpca_hplus_phase_space_density is 10% done.
# 30-Jul-21 16:02:08: mms1_hpca_hplus_phase_space_density is 10% done.
# 30-Jul-21 16:02:18: mms1_hpca_hplus_phase_space_density is 10% done.
# 30-Jul-21 16:02:29: mms1_hpca_hplus_phase_space_density is 11% done.
# 30-Jul-21 16:02:39: mms1_hpca_hplus_phase_space_density is 11% done.
# 30-Jul-21 16:02:50: mms1_hpca_hplus_phase_space_density is 11% done.
# 30-Jul-21 16:03:01: mms1_hpca_hplus_phase_space_density is 11% done.
# 30-Jul-21 16:03:11: mms1_hpca_hplus_phase_space_density is 11% done.
# 30-Jul-21 16:03:21: mms1_hpca_hplus_phase_space_density is 11% done.
# 30-Jul-21 16:03:32: mms1_hpca_hplus_phase_space_density is 12% done.
# 30-Jul-21 16:03:42: mms1_hpca_hplus_phase_space_density is 12% done.
# 30-Jul-21 16:03:52: mms1_hpca_hplus_phase_space_density is 12% done.
# 30-Jul-21 16:04:03: mms1_hpca_hplus_phase_space_density is 12% done.
# 30-Jul-21 16:04:13: mms1_hpca_hplus_phase_space_density is 12% done.
# 30-Jul-21 16:04:24: mms1_hpca_hplus_phase_space_density is 12% done.
# 30-Jul-21 16:04:34: mms1_hpca_hplus_phase_space_density is 13% done.
# 30-Jul-21 16:04:44: mms1_hpca_hplus_phase_space_density is 13% done.
# 30-Jul-21 16:04:55: mms1_hpca_hplus_phase_space_density is 13% done.
# 30-Jul-21 16:05:05: mms1_hpca_hplus_phase_space_density is 13% done.
# 30-Jul-21 16:05:15: mms1_hpca_hplus_phase_space_density is 13% done.
# 30-Jul-21 16:05:26: mms1_hpca_hplus_phase_space_density is 14% done.
# 30-Jul-21 16:05:36: mms1_hpca_hplus_phase_space_density is 14% done.
# 30-Jul-21 16:05:47: mms1_hpca_hplus_phase_space_density is 14% done.
# 30-Jul-21 16:05:57: mms1_hpca_hplus_phase_space_density is 14% done.
# 30-Jul-21 16:06:07: mms1_hpca_hplus_phase_space_density is 14% done.
# 30-Jul-21 16:06:17: mms1_hpca_hplus_phase_space_density is 14% done.
# 30-Jul-21 16:06:28: mms1_hpca_hplus_phase_space_density is 15% done.
# 30-Jul-21 16:06:38: mms1_hpca_hplus_phase_space_density is 15% done.
# 30-Jul-21 16:06:48: mms1_hpca_hplus_phase_space_density is 15% done.
# 30-Jul-21 16:06:58: mms1_hpca_hplus_phase_space_density is 15% done.
# 30-Jul-21 16:07:09: mms1_hpca_hplus_phase_space_density is 15% done.
# 30-Jul-21 16:07:19: mms1_hpca_hplus_phase_space_density is 15% done.
# 30-Jul-21 16:07:29: mms1_hpca_hplus_phase_space_density is 16% done.
# 30-Jul-21 16:07:39: mms1_hpca_hplus_phase_space_density is 16% done.
# 30-Jul-21 16:07:50: mms1_hpca_hplus_phase_space_density is 16% done.
# 30-Jul-21 16:08:00: mms1_hpca_hplus_phase_space_density is 16% done.
# 30-Jul-21 16:08:10: mms1_hpca_hplus_phase_space_density is 16% done.
# 30-Jul-21 16:08:21: mms1_hpca_hplus_phase_space_density is 17% done.
# 30-Jul-21 16:08:31: mms1_hpca_hplus_phase_space_density is 17% done.
# 30-Jul-21 16:08:42: mms1_hpca_hplus_phase_space_density is 17% done.
# 30-Jul-21 16:08:52: mms1_hpca_hplus_phase_space_density is 17% done.
# 30-Jul-21 16:09:03: mms1_hpca_hplus_phase_space_density is 17% done.
# 30-Jul-21 16:09:13: mms1_hpca_hplus_phase_space_density is 17% done.
# 30-Jul-21 16:09:23: mms1_hpca_hplus_phase_space_density is 18% done.
# 30-Jul-21 16:09:34: mms1_hpca_hplus_phase_space_density is 18% done.
# 30-Jul-21 16:09:44: mms1_hpca_hplus_phase_space_density is 18% done.
# 30-Jul-21 16:09:54: mms1_hpca_hplus_phase_space_density is 18% done.
# 30-Jul-21 16:10:05: mms1_hpca_hplus_phase_space_density is 18% done.
# 30-Jul-21 16:10:15: mms1_hpca_hplus_phase_space_density is 18% done.
# 30-Jul-21 16:10:26: mms1_hpca_hplus_phase_space_density is 19% done.
# 30-Jul-21 16:10:36: mms1_hpca_hplus_phase_space_density is 19% done.
# 30-Jul-21 16:10:46: mms1_hpca_hplus_phase_space_density is 19% done.
# 30-Jul-21 16:10:56: mms1_hpca_hplus_phase_space_density is 19% done.
# 30-Jul-21 16:11:06: mms1_hpca_hplus_phase_space_density is 19% done.
# 30-Jul-21 16:11:17: mms1_hpca_hplus_phase_space_density is 20% done.
# 30-Jul-21 16:11:27: mms1_hpca_hplus_phase_space_density is 20% done.
# 30-Jul-21 16:11:37: mms1_hpca_hplus_phase_space_density is 20% done.
# 30-Jul-21 16:11:47: mms1_hpca_hplus_phase_space_density is 20% done.
# 30-Jul-21 16:11:58: mms1_hpca_hplus_phase_space_density is 20% done.
# 30-Jul-21 16:12:08: mms1_hpca_hplus_phase_space_density is 20% done.
# 30-Jul-21 16:12:19: mms1_hpca_hplus_phase_space_density is 21% done.
# 30-Jul-21 16:12:29: mms1_hpca_hplus_phase_space_density is 21% done.
# 30-Jul-21 16:12:40: mms1_hpca_hplus_phase_space_density is 21% done.
# 30-Jul-21 16:12:50: mms1_hpca_hplus_phase_space_density is 21% done.
# 30-Jul-21 16:13:00: mms1_hpca_hplus_phase_space_density is 21% done.
# 30-Jul-21 16:13:10: mms1_hpca_hplus_phase_space_density is 22% done.
# 30-Jul-21 16:13:21: mms1_hpca_hplus_phase_space_density is 22% done.
# 30-Jul-21 16:13:31: mms1_hpca_hplus_phase_space_density is 22% done.
# 30-Jul-21 16:13:41: mms1_hpca_hplus_phase_space_density is 22% done.
# 30-Jul-21 16:13:52: mms1_hpca_hplus_phase_space_density is 22% done.
# 30-Jul-21 16:14:02: mms1_hpca_hplus_phase_space_density is 22% done.
# 30-Jul-21 16:14:12: mms1_hpca_hplus_phase_space_density is 23% done.
# 30-Jul-21 16:14:22: mms1_hpca_hplus_phase_space_density is 23% done.
# 30-Jul-21 16:14:32: mms1_hpca_hplus_phase_space_density is 23% done.
# 30-Jul-21 16:14:43: mms1_hpca_hplus_phase_space_density is 23% done.
# 30-Jul-21 16:14:53: mms1_hpca_hplus_phase_space_density is 23% done.
# 30-Jul-21 16:15:03: mms1_hpca_hplus_phase_space_density is 23% done.
# 30-Jul-21 16:15:13: mms1_hpca_hplus_phase_space_density is 24% done.
# 30-Jul-21 16:15:24: mms1_hpca_hplus_phase_space_density is 24% done.
# 30-Jul-21 16:15:34: mms1_hpca_hplus_phase_space_density is 24% done.
# 30-Jul-21 16:15:45: mms1_hpca_hplus_phase_space_density is 24% done.
# 30-Jul-21 16:15:55: mms1_hpca_hplus_phase_space_density is 24% done.
# 30-Jul-21 16:16:05: mms1_hpca_hplus_phase_space_density is 25% done.
# 30-Jul-21 16:16:15: mms1_hpca_hplus_phase_space_density is 25% done.
# 30-Jul-21 16:16:26: mms1_hpca_hplus_phase_space_density is 25% done.
# 30-Jul-21 16:16:36: mms1_hpca_hplus_phase_space_density is 25% done.
# 30-Jul-21 16:16:46: mms1_hpca_hplus_phase_space_density is 25% done.
# 30-Jul-21 16:16:57: mms1_hpca_hplus_phase_space_density is 25% done.
# 30-Jul-21 16:17:07: mms1_hpca_hplus_phase_space_density is 26% done.
# 30-Jul-21 16:17:18: mms1_hpca_hplus_phase_space_density is 26% done.
# 30-Jul-21 16:17:28: mms1_hpca_hplus_phase_space_density is 26% done.
# 30-Jul-21 16:17:38: mms1_hpca_hplus_phase_space_density is 26% done.
# 30-Jul-21 16:17:48: mms1_hpca_hplus_phase_space_density is 26% done.
# 30-Jul-21 16:17:59: mms1_hpca_hplus_phase_space_density is 26% done.
# 30-Jul-21 16:18:09: mms1_hpca_hplus_phase_space_density is 27% done.
# 30-Jul-21 16:18:19: mms1_hpca_hplus_phase_space_density is 27% done.
# 30-Jul-21 16:18:29: mms1_hpca_hplus_phase_space_density is 27% done.
# 30-Jul-21 16:18:40: mms1_hpca_hplus_phase_space_density is 27% done.
# 30-Jul-21 16:18:50: mms1_hpca_hplus_phase_space_density is 27% done.
# 30-Jul-21 16:19:00: mms1_hpca_hplus_phase_space_density is 28% done.
# 30-Jul-21 16:19:11: mms1_hpca_hplus_phase_space_density is 28% done.
# 30-Jul-21 16:19:21: mms1_hpca_hplus_phase_space_density is 28% done.
# 30-Jul-21 16:19:32: mms1_hpca_hplus_phase_space_density is 28% done.
# 30-Jul-21 16:19:42: mms1_hpca_hplus_phase_space_density is 28% done.
# 30-Jul-21 16:19:52: mms1_hpca_hplus_phase_space_density is 28% done.
# 30-Jul-21 16:20:03: mms1_hpca_hplus_phase_space_density is 29% done.
# 30-Jul-21 16:20:13: mms1_hpca_hplus_phase_space_density is 29% done.
# 30-Jul-21 16:20:23: mms1_hpca_hplus_phase_space_density is 29% done.
# 30-Jul-21 16:20:33: mms1_hpca_hplus_phase_space_density is 29% done.
# 30-Jul-21 16:20:44: mms1_hpca_hplus_phase_space_density is 29% done.
# 30-Jul-21 16:20:54: mms1_hpca_hplus_phase_space_density is 29% done.
# 30-Jul-21 16:21:05: mms1_hpca_hplus_phase_space_density is 30% done.
# 30-Jul-21 16:21:15: mms1_hpca_hplus_phase_space_density is 30% done.
# 30-Jul-21 16:21:25: mms1_hpca_hplus_phase_space_density is 30% done.
# 30-Jul-21 16:21:36: mms1_hpca_hplus_phase_space_density is 30% done.
# 30-Jul-21 16:21:46: mms1_hpca_hplus_phase_space_density is 30% done.
# 30-Jul-21 16:21:56: mms1_hpca_hplus_phase_space_density is 30% done.
# 30-Jul-21 16:22:07: mms1_hpca_hplus_phase_space_density is 31% done.
# 30-Jul-21 16:22:17: mms1_hpca_hplus_phase_space_density is 31% done.
# 30-Jul-21 16:22:27: mms1_hpca_hplus_phase_space_density is 31% done.
# 30-Jul-21 16:22:38: mms1_hpca_hplus_phase_space_density is 31% done.
# 30-Jul-21 16:22:48: mms1_hpca_hplus_phase_space_density is 31% done.
# 30-Jul-21 16:22:59: mms1_hpca_hplus_phase_space_density is 31% done.
# 30-Jul-21 16:23:09: mms1_hpca_hplus_phase_space_density is 32% done.
# 30-Jul-21 16:23:20: mms1_hpca_hplus_phase_space_density is 32% done.
# 30-Jul-21 16:23:30: mms1_hpca_hplus_phase_space_density is 32% done.
# 30-Jul-21 16:23:40: mms1_hpca_hplus_phase_space_density is 32% done.
# 30-Jul-21 16:23:50: mms1_hpca_hplus_phase_space_density is 32% done.
# 30-Jul-21 16:24:01: mms1_hpca_hplus_phase_space_density is 33% done.
# 30-Jul-21 16:24:11: mms1_hpca_hplus_phase_space_density is 33% done.
# 30-Jul-21 16:24:22: mms1_hpca_hplus_phase_space_density is 33% done.
# 30-Jul-21 16:24:32: mms1_hpca_hplus_phase_space_density is 33% done.
# 30-Jul-21 16:24:43: mms1_hpca_hplus_phase_space_density is 33% done.
# 30-Jul-21 16:24:53: mms1_hpca_hplus_phase_space_density is 33% done.
# 30-Jul-21 16:25:03: mms1_hpca_hplus_phase_space_density is 34% done.
# 30-Jul-21 16:25:14: mms1_hpca_hplus_phase_space_density is 34% done.
# 30-Jul-21 16:25:24: mms1_hpca_hplus_phase_space_density is 34% done.
# 30-Jul-21 16:25:34: mms1_hpca_hplus_phase_space_density is 34% done.
# 30-Jul-21 16:25:44: mms1_hpca_hplus_phase_space_density is 34% done.
# 30-Jul-21 16:25:55: mms1_hpca_hplus_phase_space_density is 34% done.
# 30-Jul-21 16:26:05: mms1_hpca_hplus_phase_space_density is 35% done.
# 30-Jul-21 16:26:16: mms1_hpca_hplus_phase_space_density is 35% done.
# 30-Jul-21 16:26:26: mms1_hpca_hplus_phase_space_density is 35% done.
# 30-Jul-21 16:26:36: mms1_hpca_hplus_phase_space_density is 35% done.
# 30-Jul-21 16:26:46: mms1_hpca_hplus_phase_space_density is 35% done.
# 30-Jul-21 16:26:57: mms1_hpca_hplus_phase_space_density is 35% done.
# 30-Jul-21 16:27:07: mms1_hpca_hplus_phase_space_density is 36% done.
# 30-Jul-21 16:27:18: mms1_hpca_hplus_phase_space_density is 36% done.
# 30-Jul-21 16:27:28: mms1_hpca_hplus_phase_space_density is 36% done.
# 30-Jul-21 16:27:38: mms1_hpca_hplus_phase_space_density is 36% done.
# 30-Jul-21 16:27:48: mms1_hpca_hplus_phase_space_density is 36% done.
# 30-Jul-21 16:27:59: mms1_hpca_hplus_phase_space_density is 37% done.
# 30-Jul-21 16:28:09: mms1_hpca_hplus_phase_space_density is 37% done.
# 30-Jul-21 16:28:19: mms1_hpca_hplus_phase_space_density is 37% done.
# 30-Jul-21 16:28:30: mms1_hpca_hplus_phase_space_density is 37% done.
# 30-Jul-21 16:28:40: mms1_hpca_hplus_phase_space_density is 37% done.
# 30-Jul-21 16:28:51: mms1_hpca_hplus_phase_space_density is 37% done.
# 30-Jul-21 16:29:01: mms1_hpca_hplus_phase_space_density is 38% done.
# 30-Jul-21 16:29:12: mms1_hpca_hplus_phase_space_density is 38% done.
# 30-Jul-21 16:29:22: mms1_hpca_hplus_phase_space_density is 38% done.
# 30-Jul-21 16:29:32: mms1_hpca_hplus_phase_space_density is 38% done.
# 30-Jul-21 16:29:43: mms1_hpca_hplus_phase_space_density is 38% done.
# 30-Jul-21 16:29:53: mms1_hpca_hplus_phase_space_density is 38% done.
# 30-Jul-21 16:30:03: mms1_hpca_hplus_phase_space_density is 39% done.
# 30-Jul-21 16:30:13: mms1_hpca_hplus_phase_space_density is 39% done.
# 30-Jul-21 16:30:24: mms1_hpca_hplus_phase_space_density is 39% done.
# 30-Jul-21 16:30:35: mms1_hpca_hplus_phase_space_density is 39% done.
# 30-Jul-21 16:30:45: mms1_hpca_hplus_phase_space_density is 39% done.
# 30-Jul-21 16:30:55: mms1_hpca_hplus_phase_space_density is 40% done.
# 30-Jul-21 16:31:05: mms1_hpca_hplus_phase_space_density is 40% done.
# 30-Jul-21 16:31:16: mms1_hpca_hplus_phase_space_density is 40% done.
# 30-Jul-21 16:31:26: mms1_hpca_hplus_phase_space_density is 40% done.
# 30-Jul-21 16:31:36: mms1_hpca_hplus_phase_space_density is 40% done.
# 30-Jul-21 16:31:46: mms1_hpca_hplus_phase_space_density is 40% done.
# 30-Jul-21 16:31:56: mms1_hpca_hplus_phase_space_density is 41% done.
# 30-Jul-21 16:32:06: mms1_hpca_hplus_phase_space_density is 41% done.
# 30-Jul-21 16:32:16: mms1_hpca_hplus_phase_space_density is 41% done.
# 30-Jul-21 16:32:26: mms1_hpca_hplus_phase_space_density is 41% done.
# 30-Jul-21 16:32:37: mms1_hpca_hplus_phase_space_density is 41% done.
# 30-Jul-21 16:32:48: mms1_hpca_hplus_phase_space_density is 41% done.
# 30-Jul-21 16:32:58: mms1_hpca_hplus_phase_space_density is 42% done.
# 30-Jul-21 16:33:09: mms1_hpca_hplus_phase_space_density is 42% done.
# 30-Jul-21 16:33:19: mms1_hpca_hplus_phase_space_density is 42% done.
# 30-Jul-21 16:33:30: mms1_hpca_hplus_phase_space_density is 42% done.
# 30-Jul-21 16:33:40: mms1_hpca_hplus_phase_space_density is 42% done.
# 30-Jul-21 16:33:50: mms1_hpca_hplus_phase_space_density is 43% done.
# 30-Jul-21 16:34:01: mms1_hpca_hplus_phase_space_density is 43% done.
# 30-Jul-21 16:34:11: mms1_hpca_hplus_phase_space_density is 43% done.
# 30-Jul-21 16:34:21: mms1_hpca_hplus_phase_space_density is 43% done.
# 30-Jul-21 16:34:31: mms1_hpca_hplus_phase_space_density is 43% done.
# 30-Jul-21 16:34:42: mms1_hpca_hplus_phase_space_density is 43% done.
# 30-Jul-21 16:34:52: mms1_hpca_hplus_phase_space_density is 44% done.
# 30-Jul-21 16:35:02: mms1_hpca_hplus_phase_space_density is 44% done.
# 30-Jul-21 16:35:12: mms1_hpca_hplus_phase_space_density is 44% done.
# 30-Jul-21 16:35:23: mms1_hpca_hplus_phase_space_density is 44% done.
# 30-Jul-21 16:35:33: mms1_hpca_hplus_phase_space_density is 44% done.
# 30-Jul-21 16:35:44: mms1_hpca_hplus_phase_space_density is 44% done.
# 30-Jul-21 16:35:55: mms1_hpca_hplus_phase_space_density is 45% done.
# 30-Jul-21 16:36:05: mms1_hpca_hplus_phase_space_density is 45% done.
# 30-Jul-21 16:36:15: mms1_hpca_hplus_phase_space_density is 45% done.
# 30-Jul-21 16:36:26: mms1_hpca_hplus_phase_space_density is 45% done.
# 30-Jul-21 16:36:36: mms1_hpca_hplus_phase_space_density is 45% done.
# 30-Jul-21 16:36:47: mms1_hpca_hplus_phase_space_density is 45% done.
# 30-Jul-21 16:36:57: mms1_hpca_hplus_phase_space_density is 46% done.
# 30-Jul-21 16:37:08: mms1_hpca_hplus_phase_space_density is 46% done.
# 30-Jul-21 16:37:19: mms1_hpca_hplus_phase_space_density is 46% done.
# 30-Jul-21 16:37:29: mms1_hpca_hplus_phase_space_density is 46% done.
# 30-Jul-21 16:37:41: mms1_hpca_hplus_phase_space_density is 46% done.
# 30-Jul-21 16:37:51: mms1_hpca_hplus_phase_space_density is 46% done.
# 30-Jul-21 16:38:02: mms1_hpca_hplus_phase_space_density is 46% done.
# 30-Jul-21 16:38:12: mms1_hpca_hplus_phase_space_density is 46% done.
# 30-Jul-21 16:38:23: mms1_hpca_hplus_phase_space_density is 47% done.
# 30-Jul-21 16:38:33: mms1_hpca_hplus_phase_space_density is 47% done.
# 30-Jul-21 16:38:44: mms1_hpca_hplus_phase_space_density is 47% done.
# 30-Jul-21 16:38:55: mms1_hpca_hplus_phase_space_density is 47% done.
# 30-Jul-21 16:39:05: mms1_hpca_hplus_phase_space_density is 47% done.
# 30-Jul-21 16:39:15: mms1_hpca_hplus_phase_space_density is 47% done.
# 30-Jul-21 16:39:26: mms1_hpca_hplus_phase_space_density is 47% done.
# 30-Jul-21 16:39:36: mms1_hpca_hplus_phase_space_density is 48% done.
# 30-Jul-21 16:39:47: mms1_hpca_hplus_phase_space_density is 48% done.
# 30-Jul-21 16:39:57: mms1_hpca_hplus_phase_space_density is 48% done.
# 30-Jul-21 16:40:07: mms1_hpca_hplus_phase_space_density is 48% done.
# 30-Jul-21 16:40:18: mms1_hpca_hplus_phase_space_density is 48% done.
# 30-Jul-21 16:40:28: mms1_hpca_hplus_phase_space_density is 48% done.
# 30-Jul-21 16:40:39: mms1_hpca_hplus_phase_space_density is 48% done.
# 30-Jul-21 16:40:49: mms1_hpca_hplus_phase_space_density is 49% done.
# 30-Jul-21 16:40:59: mms1_hpca_hplus_phase_space_density is 49% done.
# 30-Jul-21 16:41:10: mms1_hpca_hplus_phase_space_density is 49% done.
# 30-Jul-21 16:41:20: mms1_hpca_hplus_phase_space_density is 49% done.
# 30-Jul-21 16:41:31: mms1_hpca_hplus_phase_space_density is 49% done.
# 30-Jul-21 16:41:41: mms1_hpca_hplus_phase_space_density is 50% done.
# 30-Jul-21 16:41:52: mms1_hpca_hplus_phase_space_density is 50% done.
# 30-Jul-21 16:42:02: mms1_hpca_hplus_phase_space_density is 50% done.
# 30-Jul-21 16:42:13: mms1_hpca_hplus_phase_space_density is 50% done.
# 30-Jul-21 16:42:23: mms1_hpca_hplus_phase_space_density is 50% done.
# 30-Jul-21 16:42:34: mms1_hpca_hplus_phase_space_density is 50% done.
# 30-Jul-21 16:42:44: mms1_hpca_hplus_phase_space_density is 51% done.
# 30-Jul-21 16:42:54: mms1_hpca_hplus_phase_space_density is 51% done.
# 30-Jul-21 16:43:04: mms1_hpca_hplus_phase_space_density is 51% done.
# 30-Jul-21 16:43:15: mms1_hpca_hplus_phase_space_density is 51% done.
# 30-Jul-21 16:43:26: mms1_hpca_hplus_phase_space_density is 51% done.
# 30-Jul-21 16:43:36: mms1_hpca_hplus_phase_space_density is 51% done.
# 30-Jul-21 16:43:46: mms1_hpca_hplus_phase_space_density is 52% done.
# 30-Jul-21 16:43:57: mms1_hpca_hplus_phase_space_density is 52% done.
# 30-Jul-21 16:44:07: mms1_hpca_hplus_phase_space_density is 52% done.
# 30-Jul-21 16:44:17: mms1_hpca_hplus_phase_space_density is 52% done.
# 30-Jul-21 16:44:28: mms1_hpca_hplus_phase_space_density is 52% done.
# 30-Jul-21 16:44:39: mms1_hpca_hplus_phase_space_density is 53% done.
# 30-Jul-21 16:44:49: mms1_hpca_hplus_phase_space_density is 53% done.
# 30-Jul-21 16:45:00: mms1_hpca_hplus_phase_space_density is 53% done.
# 30-Jul-21 16:45:10: mms1_hpca_hplus_phase_space_density is 53% done.
# 30-Jul-21 16:45:21: mms1_hpca_hplus_phase_space_density is 53% done.
# 30-Jul-21 16:45:31: mms1_hpca_hplus_phase_space_density is 53% done.
# 30-Jul-21 16:45:42: mms1_hpca_hplus_phase_space_density is 54% done.
# 30-Jul-21 16:45:53: mms1_hpca_hplus_phase_space_density is 54% done.
# 30-Jul-21 16:46:03: mms1_hpca_hplus_phase_space_density is 54% done.
# 30-Jul-21 16:46:13: mms1_hpca_hplus_phase_space_density is 54% done.
# 30-Jul-21 16:46:23: mms1_hpca_hplus_phase_space_density is 54% done.
# 30-Jul-21 16:46:34: mms1_hpca_hplus_phase_space_density is 54% done.
# 30-Jul-21 16:46:45: mms1_hpca_hplus_phase_space_density is 55% done.
# 30-Jul-21 16:46:55: mms1_hpca_hplus_phase_space_density is 55% done.
# 30-Jul-21 16:47:05: mms1_hpca_hplus_phase_space_density is 55% done.
# 30-Jul-21 16:47:16: mms1_hpca_hplus_phase_space_density is 55% done.
# 30-Jul-21 16:47:26: mms1_hpca_hplus_phase_space_density is 55% done.
# 30-Jul-21 16:47:37: mms1_hpca_hplus_phase_space_density is 56% done.
# 30-Jul-21 16:47:47: mms1_hpca_hplus_phase_space_density is 56% done.
# 30-Jul-21 16:47:58: mms1_hpca_hplus_phase_space_density is 56% done.
# 30-Jul-21 16:48:08: mms1_hpca_hplus_phase_space_density is 56% done.
# 30-Jul-21 16:48:19: mms1_hpca_hplus_phase_space_density is 56% done.
# 30-Jul-21 16:48:29: mms1_hpca_hplus_phase_space_density is 56% done.
# 30-Jul-21 16:48:39: mms1_hpca_hplus_phase_space_density is 57% done.
# 30-Jul-21 16:48:50: mms1_hpca_hplus_phase_space_density is 57% done.
# 30-Jul-21 16:49:00: mms1_hpca_hplus_phase_space_density is 57% done.
# 30-Jul-21 16:49:10: mms1_hpca_hplus_phase_space_density is 57% done.
# 30-Jul-21 16:49:21: mms1_hpca_hplus_phase_space_density is 57% done.
# 30-Jul-21 16:49:31: mms1_hpca_hplus_phase_space_density is 57% done.
# 30-Jul-21 16:49:41: mms1_hpca_hplus_phase_space_density is 58% done.
# 30-Jul-21 16:49:52: mms1_hpca_hplus_phase_space_density is 58% done.
# 30-Jul-21 16:50:02: mms1_hpca_hplus_phase_space_density is 58% done.
# 30-Jul-21 16:50:12: mms1_hpca_hplus_phase_space_density is 58% done.
# 30-Jul-21 16:50:22: mms1_hpca_hplus_phase_space_density is 58% done.
# 30-Jul-21 16:50:33: mms1_hpca_hplus_phase_space_density is 59% done.
# 30-Jul-21 16:50:43: mms1_hpca_hplus_phase_space_density is 59% done.
# 30-Jul-21 16:50:54: mms1_hpca_hplus_phase_space_density is 59% done.
# 30-Jul-21 16:51:04: mms1_hpca_hplus_phase_space_density is 59% done.
# 30-Jul-21 16:51:14: mms1_hpca_hplus_phase_space_density is 59% done.
# 30-Jul-21 16:51:24: mms1_hpca_hplus_phase_space_density is 59% done.
# 30-Jul-21 16:51:34: mms1_hpca_hplus_phase_space_density is 60% done.
# 30-Jul-21 16:51:45: mms1_hpca_hplus_phase_space_density is 60% done.
# 30-Jul-21 16:51:55: mms1_hpca_hplus_phase_space_density is 60% done.
# 30-Jul-21 16:52:06: mms1_hpca_hplus_phase_space_density is 60% done.
# 30-Jul-21 16:52:16: mms1_hpca_hplus_phase_space_density is 60% done.
# 30-Jul-21 16:52:26: mms1_hpca_hplus_phase_space_density is 60% done.
# 30-Jul-21 16:52:37: mms1_hpca_hplus_phase_space_density is 61% done.
# 30-Jul-21 16:52:47: mms1_hpca_hplus_phase_space_density is 61% done.
# 30-Jul-21 16:52:57: mms1_hpca_hplus_phase_space_density is 61% done.
# 30-Jul-21 16:53:07: mms1_hpca_hplus_phase_space_density is 61% done.
# 30-Jul-21 16:53:18: mms1_hpca_hplus_phase_space_density is 61% done.
# 30-Jul-21 16:53:28: mms1_hpca_hplus_phase_space_density is 62% done.
# 30-Jul-21 16:53:39: mms1_hpca_hplus_phase_space_density is 62% done.
# 30-Jul-21 16:53:49: mms1_hpca_hplus_phase_space_density is 62% done.
# 30-Jul-21 16:54:00: mms1_hpca_hplus_phase_space_density is 62% done.
# 30-Jul-21 16:54:10: mms1_hpca_hplus_phase_space_density is 62% done.
# 30-Jul-21 16:54:20: mms1_hpca_hplus_phase_space_density is 62% done.
# 30-Jul-21 16:54:30: mms1_hpca_hplus_phase_space_density is 63% done.
# 30-Jul-21 16:54:41: mms1_hpca_hplus_phase_space_density is 63% done.
# 30-Jul-21 16:54:51: mms1_hpca_hplus_phase_space_density is 63% done.
# 30-Jul-21 16:55:01: mms1_hpca_hplus_phase_space_density is 63% done.
# 30-Jul-21 16:55:12: mms1_hpca_hplus_phase_space_density is 63% done.
# 30-Jul-21 16:55:22: mms1_hpca_hplus_phase_space_density is 63% done.
# 30-Jul-21 16:55:32: mms1_hpca_hplus_phase_space_density is 64% done.
# 30-Jul-21 16:55:43: mms1_hpca_hplus_phase_space_density is 64% done.
# 30-Jul-21 16:55:53: mms1_hpca_hplus_phase_space_density is 64% done.
# 30-Jul-21 16:56:04: mms1_hpca_hplus_phase_space_density is 64% done.
# 30-Jul-21 16:56:14: mms1_hpca_hplus_phase_space_density is 64% done.
# 30-Jul-21 16:56:24: mms1_hpca_hplus_phase_space_density is 65% done.
# 30-Jul-21 16:56:34: mms1_hpca_hplus_phase_space_density is 65% done.
# 30-Jul-21 16:56:44: mms1_hpca_hplus_phase_space_density is 65% done.
# 30-Jul-21 16:56:55: mms1_hpca_hplus_phase_space_density is 65% done.
# 30-Jul-21 16:57:05: mms1_hpca_hplus_phase_space_density is 65% done.
# 30-Jul-21 16:57:16: mms1_hpca_hplus_phase_space_density is 65% done.
# 30-Jul-21 16:57:27: mms1_hpca_hplus_phase_space_density is 66% done.
# 30-Jul-21 16:57:37: mms1_hpca_hplus_phase_space_density is 66% done.
# 30-Jul-21 16:57:47: mms1_hpca_hplus_phase_space_density is 66% done.
# 30-Jul-21 16:57:58: mms1_hpca_hplus_phase_space_density is 66% done.
# 30-Jul-21 16:58:08: mms1_hpca_hplus_phase_space_density is 66% done.
# 30-Jul-21 16:58:18: mms1_hpca_hplus_phase_space_density is 66% done.
# 30-Jul-21 16:58:29: mms1_hpca_hplus_phase_space_density is 67% done.
# 30-Jul-21 16:58:39: mms1_hpca_hplus_phase_space_density is 67% done.
# 30-Jul-21 16:58:49: mms1_hpca_hplus_phase_space_density is 67% done.
# 30-Jul-21 16:59:00: mms1_hpca_hplus_phase_space_density is 67% done.
# 30-Jul-21 16:59:10: mms1_hpca_hplus_phase_space_density is 67% done.
# 30-Jul-21 16:59:20: mms1_hpca_hplus_phase_space_density is 67% done.
# 30-Jul-21 16:59:30: mms1_hpca_hplus_phase_space_density is 68% done.
# 30-Jul-21 16:59:41: mms1_hpca_hplus_phase_space_density is 68% done.
# 30-Jul-21 16:59:51: mms1_hpca_hplus_phase_space_density is 68% done.
# 30-Jul-21 17:00:02: mms1_hpca_hplus_phase_space_density is 68% done.
# 30-Jul-21 17:00:12: mms1_hpca_hplus_phase_space_density is 68% done.
# 30-Jul-21 17:00:22: mms1_hpca_hplus_phase_space_density is 69% done.
# 30-Jul-21 17:00:32: mms1_hpca_hplus_phase_space_density is 69% done.
# 30-Jul-21 17:00:43: mms1_hpca_hplus_phase_space_density is 69% done.
# 30-Jul-21 17:00:53: mms1_hpca_hplus_phase_space_density is 69% done.
# 30-Jul-21 17:01:04: mms1_hpca_hplus_phase_space_density is 69% done.
# 30-Jul-21 17:01:14: mms1_hpca_hplus_phase_space_density is 69% done.
# 30-Jul-21 17:01:25: mms1_hpca_hplus_phase_space_density is 70% done.
# 30-Jul-21 17:01:35: mms1_hpca_hplus_phase_space_density is 70% done.
# 30-Jul-21 17:01:45: mms1_hpca_hplus_phase_space_density is 70% done.
# 30-Jul-21 17:01:56: mms1_hpca_hplus_phase_space_density is 70% done.
# 30-Jul-21 17:02:06: mms1_hpca_hplus_phase_space_density is 70% done.
# 30-Jul-21 17:02:16: mms1_hpca_hplus_phase_space_density is 70% done.
# 30-Jul-21 17:02:26: mms1_hpca_hplus_phase_space_density is 71% done.
# 30-Jul-21 17:02:37: mms1_hpca_hplus_phase_space_density is 71% done.
# 30-Jul-21 17:02:47: mms1_hpca_hplus_phase_space_density is 71% done.
# 30-Jul-21 17:02:57: mms1_hpca_hplus_phase_space_density is 71% done.
# 30-Jul-21 17:03:08: mms1_hpca_hplus_phase_space_density is 71% done.
# 30-Jul-21 17:03:18: mms1_hpca_hplus_phase_space_density is 72% done.
# 30-Jul-21 17:03:28: mms1_hpca_hplus_phase_space_density is 72% done.
# 30-Jul-21 17:03:39: mms1_hpca_hplus_phase_space_density is 72% done.
# 30-Jul-21 17:03:49: mms1_hpca_hplus_phase_space_density is 72% done.
# 30-Jul-21 17:04:00: mms1_hpca_hplus_phase_space_density is 72% done.
# 30-Jul-21 17:04:10: mms1_hpca_hplus_phase_space_density is 72% done.
# 30-Jul-21 17:04:21: mms1_hpca_hplus_phase_space_density is 73% done.
# 30-Jul-21 17:04:31: mms1_hpca_hplus_phase_space_density is 73% done.
# 30-Jul-21 17:04:43: mms1_hpca_hplus_phase_space_density is 73% done.
# 30-Jul-21 17:04:53: mms1_hpca_hplus_phase_space_density is 73% done.
# 30-Jul-21 17:05:04: mms1_hpca_hplus_phase_space_density is 73% done.
# 30-Jul-21 17:05:14: mms1_hpca_hplus_phase_space_density is 73% done.
# 30-Jul-21 17:05:25: mms1_hpca_hplus_phase_space_density is 74% done.
# 30-Jul-21 17:05:35: mms1_hpca_hplus_phase_space_density is 74% done.
# 30-Jul-21 17:05:46: mms1_hpca_hplus_phase_space_density is 74% done.
# 30-Jul-21 17:05:56: mms1_hpca_hplus_phase_space_density is 74% done.
# 30-Jul-21 17:06:06: mms1_hpca_hplus_phase_space_density is 74% done.
# 30-Jul-21 17:06:17: mms1_hpca_hplus_phase_space_density is 74% done.
# 30-Jul-21 17:06:27: mms1_hpca_hplus_phase_space_density is 75% done.
# 30-Jul-21 17:06:37: mms1_hpca_hplus_phase_space_density is 75% done.
# 30-Jul-21 17:06:47: mms1_hpca_hplus_phase_space_density is 75% done.
# 30-Jul-21 17:06:58: mms1_hpca_hplus_phase_space_density is 75% done.
# 30-Jul-21 17:07:08: mms1_hpca_hplus_phase_space_density is 75% done.
# 30-Jul-21 17:07:18: mms1_hpca_hplus_phase_space_density is 75% done.
# 30-Jul-21 17:07:29: mms1_hpca_hplus_phase_space_density is 76% done.
# 30-Jul-21 17:07:39: mms1_hpca_hplus_phase_space_density is 76% done.
# 30-Jul-21 17:07:50: mms1_hpca_hplus_phase_space_density is 76% done.
# 30-Jul-21 17:08:00: mms1_hpca_hplus_phase_space_density is 76% done.
# 30-Jul-21 17:08:11: mms1_hpca_hplus_phase_space_density is 76% done.
# 30-Jul-21 17:08:21: mms1_hpca_hplus_phase_space_density is 76% done.
# 30-Jul-21 17:08:31: mms1_hpca_hplus_phase_space_density is 77% done.
# 30-Jul-21 17:08:41: mms1_hpca_hplus_phase_space_density is 77% done.
# 30-Jul-21 17:08:52: mms1_hpca_hplus_phase_space_density is 77% done.
# 30-Jul-21 17:09:02: mms1_hpca_hplus_phase_space_density is 77% done.
# 30-Jul-21 17:09:13: mms1_hpca_hplus_phase_space_density is 77% done.
# 30-Jul-21 17:09:23: mms1_hpca_hplus_phase_space_density is 77% done.
# 30-Jul-21 17:09:34: mms1_hpca_hplus_phase_space_density is 77% done.
# 30-Jul-21 17:09:44: mms1_hpca_hplus_phase_space_density is 78% done.
# 30-Jul-21 17:09:54: mms1_hpca_hplus_phase_space_density is 78% done.
# 30-Jul-21 17:10:04: mms1_hpca_hplus_phase_space_density is 78% done.
# 30-Jul-21 17:10:15: mms1_hpca_hplus_phase_space_density is 78% done.
# 30-Jul-21 17:10:25: mms1_hpca_hplus_phase_space_density is 78% done.
# 30-Jul-21 17:10:36: mms1_hpca_hplus_phase_space_density is 78% done.
# 30-Jul-21 17:10:46: mms1_hpca_hplus_phase_space_density is 79% done.
# 30-Jul-21 17:10:57: mms1_hpca_hplus_phase_space_density is 79% done.
# 30-Jul-21 17:11:07: mms1_hpca_hplus_phase_space_density is 79% done.
# 30-Jul-21 17:11:18: mms1_hpca_hplus_phase_space_density is 79% done.
# 30-Jul-21 17:11:28: mms1_hpca_hplus_phase_space_density is 79% done.
# 30-Jul-21 17:11:39: mms1_hpca_hplus_phase_space_density is 79% done.
# 30-Jul-21 17:11:50: mms1_hpca_hplus_phase_space_density is 80% done.
# 30-Jul-21 17:12:00: mms1_hpca_hplus_phase_space_density is 80% done.
# 30-Jul-21 17:12:10: mms1_hpca_hplus_phase_space_density is 80% done.
# 30-Jul-21 17:12:20: mms1_hpca_hplus_phase_space_density is 80% done.
# 30-Jul-21 17:12:31: mms1_hpca_hplus_phase_space_density is 80% done.
# 30-Jul-21 17:12:41: mms1_hpca_hplus_phase_space_density is 80% done.
# 30-Jul-21 17:12:51: mms1_hpca_hplus_phase_space_density is 81% done.
# 30-Jul-21 17:13:02: mms1_hpca_hplus_phase_space_density is 81% done.
# 30-Jul-21 17:13:12: mms1_hpca_hplus_phase_space_density is 81% done.
# 30-Jul-21 17:13:23: mms1_hpca_hplus_phase_space_density is 81% done.
# 30-Jul-21 17:13:33: mms1_hpca_hplus_phase_space_density is 81% done.
# 30-Jul-21 17:13:44: mms1_hpca_hplus_phase_space_density is 81% done.
# 30-Jul-21 17:13:54: mms1_hpca_hplus_phase_space_density is 82% done.
# 30-Jul-21 17:14:04: mms1_hpca_hplus_phase_space_density is 82% done.
# 30-Jul-21 17:14:15: mms1_hpca_hplus_phase_space_density is 82% done.
# 30-Jul-21 17:14:25: mms1_hpca_hplus_phase_space_density is 82% done.
# 30-Jul-21 17:14:36: mms1_hpca_hplus_phase_space_density is 82% done.
# 30-Jul-21 17:14:46: mms1_hpca_hplus_phase_space_density is 82% done.
# 30-Jul-21 17:14:57: mms1_hpca_hplus_phase_space_density is 83% done.
# 30-Jul-21 17:14:59: c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\pyspedas\particles\moments\moments_3d.py:90: RuntimeWarning: invalid value encountered in true_divide
#   velocity = flux/density/1e5 # km/s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18204/1035861121.py in <module>
# ----> 1 mms_part_getspec(trange=['2019-10-16', '2019-10-17'],
#       2                  instrument='hpca',
#       3                  probe=1,
#       4                  species='hplus',
#       5                  output=['phi', 'theta', 'energy', 'pa', 'gyro', 'moments'])
#
# c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\pyspedas\mms\particles\mms_part_getspec.py in mms_part_getspec(instrument, probe, species, data_rate, trange, output, units, energy, phi, theta, pitch, gyro, mag_data_rate, fac_type, center_measurement, spdf, correct_photoelectrons, internal_photoelectron_corrections, disable_photoelectron_corrections)
#      97         scpot_variable = 'mms'+prb_str+'_edp_scpot_'+scpot_data_rate+'_l2'
#      98
# ---> 99         new_vars = mms_part_products(tname, species=species, instrument=instrument, probe=prb, data_rate=data_rate,
#     100                           output=output, units=units, energy=energy, phi=phi, theta=theta, pitch=pitch, gyro=gyro,
#     101                           mag_name=mag_name, pos_name=pos_name, fac_type=fac_type, sc_pot_name=scpot_variable,
#
# c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\pyspedas\mms\particles\mms_part_products.py in mms_part_products(in_tvarname, units, species, data_rate, instrument, probe, output, energy, phi, theta, pitch, gyro, mag_name, pos_name, fac_type, sc_pot_name, correct_photoelectrons, internal_photoelectron_corrections, disable_photoelectron_corrections)
#     203                 scpot_val = 0.0
#     204
# --> 205             moments = spd_pgs_moments(clean_data, sc_pot=scpot_val)
#     206             out_density[i] = moments['density']
#     207             out_avgtemp[i] = moments['avgtemp']
#
# c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\pyspedas\particles\moments\spd_pgs_moments.py in spd_pgs_moments(data_in, sc_pot)
#      20     """
#      21
# ---> 22     return moments_3d(data_in, sc_pot=sc_pot)
#
# c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\pyspedas\particles\moments\moments_3d.py in moments_3d(data_in, sc_pot, no_unit_conversion)
#      99     vthermal = np.sqrt(2.0*avgtemp/mass)
#     100
# --> 101     t3 = sp.linalg.svdvals(t3x3)
#     102
#     103     output = {'density': density,
#
# c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\scipy\linalg\decomp_svd.py in svdvals(a, overwrite_a, check_finite)
#     220
#     221     """
# --> 222     a = _asarray_validated(a, check_finite=check_finite)
#     223     if a.size:
#     224         return svd(a, compute_uv=0, overwrite_a=overwrite_a,
#
# c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\scipy\_lib\_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     270             raise ValueError('masked arrays are not supported')
#     271     toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 272     a = toarray(a)
#     273     if not objects_ok:
#     274         if a.dtype is np.dtype('O'):
#
# c:\users\egrimes\appdata\local\programs\python\python39\lib\site-packages\numpy\lib\function_base.py in asarray_chkfinite(a, dtype, order)
#     486     a = asarray(a, dtype=dtype, order=order)
#     487     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 488         raise ValueError(
#     489             "array must not contain infs or NaNs")
#     490     return a
#
# ValueError: array must not contain infs or NaNs
