# %% [markdown]
# # Fast Plasma Investigation (FPI)
#
# This notebook shows how to load and plot MMS FPI data with pySPEDAS and pyTplot
#
# For information on the data, please see the Release Notes and Data Products Guide at:
#
# https://lasp.colorado.edu/mms/sdc/public/datasets/fpi/

# %% [markdown]
# This command sets up the PySPEDAS environment when running in Google Colab.  You can skip it or comment it out if you're running this notebook in an environment that already has PySPEDAS installed.

# %%
# !pip install pyspedas

# %% [markdown]
# ## Get started
#
# To get started, import the `fpi` function from the `pyspedas.projects.mms` module, and `tplot` from `pyspedas`

# %%
from pyspedas.projects.mms import fpi
from pyspedas import tplot

# %% [markdown]
# ## Load the electron moments data

# %%
electron_vars = fpi(datatype='des-moms', trange=['2015-10-16', '2015-10-17'], center_measurement=True)
# Out:
# 08-Dec-23 11:14:53: Downloading mms1_fpi_fast_l2_des-moms_20151016040000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/des-moms/2015/10
# 08-Dec-23 11:14:55: Downloading mms1_fpi_fast_l2_des-moms_20151016060000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/des-moms/2015/10
# 08-Dec-23 11:14:59: Downloading mms1_fpi_fast_l2_des-moms_20151016080000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/des-moms/2015/10
# 08-Dec-23 11:15:01: Loading pydata/mms1/fpi/fast/l2/des-moms/2015/10/mms1_fpi_fast_l2_des-moms_20151016100000_v3.4.0.cdf
# 08-Dec-23 11:15:01: Loading pydata/mms1/fpi/fast/l2/des-moms/2015/10/mms1_fpi_fast_l2_des-moms_20151016120000_v3.4.0.cdf
# 08-Dec-23 11:15:01: Downloading mms1_fpi_fast_l2_des-moms_20151016140000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/des-moms/2015/10
# 08-Dec-23 11:15:04: Downloading mms1_fpi_fast_l2_des-moms_20151016160000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/des-moms/2015/10
# 08-Dec-23 11:15:07: Loaded variables:
# 08-Dec-23 11:15:07: Epoch
# 08-Dec-23 11:15:07: Epoch_plus_var
# 08-Dec-23 11:15:07: Epoch_minus_var
# 08-Dec-23 11:15:07: mms1_des_errorflags_fast
# 08-Dec-23 11:15:07: mms1_des_compressionloss_fast
# 08-Dec-23 11:15:07: mms1_des_startdelphi_count_fast
# 08-Dec-23 11:15:07: mms1_des_startdelphi_angle_fast
# 08-Dec-23 11:15:07: mms1_des_pitchangdist_lowen_fast
# 08-Dec-23 11:15:07: mms1_des_pitchangdist_miden_fast
# 08-Dec-23 11:15:07: mms1_des_pitchangdist_highen_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_px_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_mx_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_py_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_my_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_pz_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_mz_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_par_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_anti_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_perp_fast
# 08-Dec-23 11:15:07: mms1_des_energyspectr_omni_fast
# 08-Dec-23 11:15:07: mms1_des_numberdensity_fast
# 08-Dec-23 11:15:07: mms1_des_numberdensity_err_fast
# 08-Dec-23 11:15:07: mms1_des_densityextrapolation_low_fast
# 08-Dec-23 11:15:07: mms1_des_densityextrapolation_high_fast
# 08-Dec-23 11:15:07: mms1_des_bulkv_dbcs_fast
# 08-Dec-23 11:15:07: mms1_des_bulkv_spintone_dbcs_fast
# 08-Dec-23 11:15:07: mms1_des_bulkv_gse_fast
# 08-Dec-23 11:15:07: mms1_des_bulkv_spintone_gse_fast
# 08-Dec-23 11:15:07: mms1_des_bulkv_err_fast
# 08-Dec-23 11:15:07: mms1_des_prestensor_dbcs_fast
# 08-Dec-23 11:15:07: mms1_des_prestensor_gse_fast
# 08-Dec-23 11:15:07: mms1_des_prestensor_err_fast
# 08-Dec-23 11:15:07: mms1_des_temptensor_dbcs_fast
# 08-Dec-23 11:15:07: mms1_des_temptensor_gse_fast
# 08-Dec-23 11:15:07: mms1_des_temptensor_err_fast
# 08-Dec-23 11:15:07: mms1_des_heatq_dbcs_fast
# 08-Dec-23 11:15:07: mms1_des_heatq_gse_fast
# 08-Dec-23 11:15:07: mms1_des_heatq_err_fast
# 08-Dec-23 11:15:07: mms1_des_alpha_fast
# 08-Dec-23 11:15:07: mms1_des_alpha_delta_fast
# 08-Dec-23 11:15:07: mms1_des_energy_fast
# 08-Dec-23 11:15:07: mms1_des_energy_delta_fast
# 08-Dec-23 11:15:07: mms1_des_temppara_fast
# 08-Dec-23 11:15:07: mms1_des_tempperp_fast
# 08-Dec-23 11:15:07: mms1_des_errorflags_fast_moms
# 08-Dec-23 11:15:07: mms1_des_compressionloss_fast_moms
# 08-Dec-23 11:15:07: mms1_des_pitchangdist_avg
# 08-Dec-23 11:15:07: mms1_des_errorflags_fast_moms_flagbars_full
# 08-Dec-23 11:15:07: mms1_des_errorflags_fast_moms_flagbars_main
# 08-Dec-23 11:15:07: mms1_des_errorflags_fast_moms_flagbars_others
# 08-Dec-23 11:15:07: mms1_des_errorflags_fast_moms_flagbars_mini

# %% [markdown]
# ## Plot the electron data

# %%
tplot(['mms1_des_energyspectr_omni_fast', 'mms1_des_bulkv_gse_fast', 'mms1_des_numberdensity_fast'])

# %% [markdown]
# ## Load the ion moments data

# %%
ion_vars = fpi(datatype='dis-moms', trange=['2015-10-16', '2015-10-17'], center_measurement=True)
# Out:
# 08-Dec-23 11:15:14: Downloading mms1_fpi_fast_l2_dis-moms_20151016040000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/dis-moms/2015/10
# 08-Dec-23 11:15:15: Downloading mms1_fpi_fast_l2_dis-moms_20151016060000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/dis-moms/2015/10
# 08-Dec-23 11:15:18: Downloading mms1_fpi_fast_l2_dis-moms_20151016080000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/dis-moms/2015/10
# 08-Dec-23 11:15:20: Loading pydata/mms1/fpi/fast/l2/dis-moms/2015/10/mms1_fpi_fast_l2_dis-moms_20151016100000_v3.4.0.cdf
# 08-Dec-23 11:15:20: Loading pydata/mms1/fpi/fast/l2/dis-moms/2015/10/mms1_fpi_fast_l2_dis-moms_20151016120000_v3.4.0.cdf
# 08-Dec-23 11:15:20: Downloading mms1_fpi_fast_l2_dis-moms_20151016140000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/dis-moms/2015/10
# 08-Dec-23 11:15:24: Downloading mms1_fpi_fast_l2_dis-moms_20151016160000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/dis-moms/2015/10
# 08-Dec-23 11:15:26: The name mms1_dis_pitchangdist_lowen_fast is currently not in pytplot
# 08-Dec-23 11:15:26: The name mms1_dis_pitchangdist_miden_fast is currently not in pytplot
# 08-Dec-23 11:15:26: The name mms1_dis_pitchangdist_highen_fast is currently not in pytplot
# 08-Dec-23 11:15:26: Loaded variables:
# 08-Dec-23 11:15:26: Epoch
# 08-Dec-23 11:15:26: Epoch_plus_var
# 08-Dec-23 11:15:26: Epoch_minus_var
# 08-Dec-23 11:15:26: mms1_dis_errorflags_fast
# 08-Dec-23 11:15:26: mms1_dis_compressionloss_fast
# 08-Dec-23 11:15:26: mms1_dis_startdelphi_count_fast
# 08-Dec-23 11:15:26: mms1_dis_startdelphi_angle_fast
# 08-Dec-23 11:15:26: mms1_dis_energyspectr_px_fast
# 08-Dec-23 11:15:26: mms1_dis_energyspectr_mx_fast
# 08-Dec-23 11:15:26: mms1_dis_energyspectr_py_fast
# 08-Dec-23 11:15:26: mms1_dis_energyspectr_my_fast
# 08-Dec-23 11:15:26: mms1_dis_energyspectr_pz_fast
# 08-Dec-23 11:15:26: mms1_dis_energyspectr_mz_fast
# 08-Dec-23 11:15:26: mms1_dis_energyspectr_omni_fast
# 08-Dec-23 11:15:26: mms1_dis_spectr_bg_fast
# 08-Dec-23 11:15:26: mms1_dis_numberdensity_bg_fast
# 08-Dec-23 11:15:26: mms1_dis_numberdensity_fast
# 08-Dec-23 11:15:26: mms1_dis_numberdensity_err_fast
# 08-Dec-23 11:15:26: mms1_dis_densityextrapolation_low_fast
# 08-Dec-23 11:15:26: mms1_dis_densityextrapolation_high_fast
# 08-Dec-23 11:15:26: mms1_dis_bulkv_dbcs_fast
# 08-Dec-23 11:15:26: mms1_dis_bulkv_spintone_dbcs_fast
# 08-Dec-23 11:15:26: mms1_dis_bulkv_gse_fast
# 08-Dec-23 11:15:26: mms1_dis_bulkv_spintone_gse_fast
# 08-Dec-23 11:15:26: mms1_dis_bulkv_err_fast
# 08-Dec-23 11:15:26: mms1_dis_prestensor_dbcs_fast
# 08-Dec-23 11:15:26: mms1_dis_prestensor_gse_fast
# 08-Dec-23 11:15:26: mms1_dis_prestensor_err_fast
# 08-Dec-23 11:15:26: mms1_dis_pres_bg_fast
# 08-Dec-23 11:15:26: mms1_dis_temptensor_dbcs_fast
# 08-Dec-23 11:15:26: mms1_dis_temptensor_gse_fast
# 08-Dec-23 11:15:26: mms1_dis_temptensor_err_fast
# 08-Dec-23 11:15:26: mms1_dis_heatq_dbcs_fast
# 08-Dec-23 11:15:26: mms1_dis_heatq_gse_fast
# 08-Dec-23 11:15:26: mms1_dis_heatq_err_fast
# 08-Dec-23 11:15:26: mms1_dis_energy_fast
# 08-Dec-23 11:15:26: mms1_dis_energy_delta_fast
# 08-Dec-23 11:15:26: mms1_dis_temppara_fast
# 08-Dec-23 11:15:26: mms1_dis_tempperp_fast
# 08-Dec-23 11:15:26: mms1_dis_errorflags_fast_moms
# 08-Dec-23 11:15:26: mms1_dis_compressionloss_fast_moms
# 08-Dec-23 11:15:26: mms1_dis_errorflags_fast_moms_flagbars_full
# 08-Dec-23 11:15:26: mms1_dis_errorflags_fast_moms_flagbars_main
# 08-Dec-23 11:15:26: mms1_dis_errorflags_fast_moms_flagbars_others
# 08-Dec-23 11:15:26: mms1_dis_errorflags_fast_moms_flagbars_mini

# %% [markdown]
# ## Plot the ion data

# %%
tplot(['mms1_dis_energyspectr_omni_fast', 'mms1_dis_bulkv_gse_fast', 'mms1_dis_numberdensity_fast'])

# %% [markdown]
# ## Load the burst mode data for both electrons and ions

# %%
both_vars = fpi(data_rate='brst', trange=['2015-10-16/13:06', '2015-10-16/13:07'], center_measurement=True)
# Out:
# 08-Dec-23 11:15:34: Downloading mms1_fpi_brst_l2_des-dist_20151016130524_v3.3.0.cdf to pydata/mms1/fpi/brst/l2/des-dist/2015/10/16
# 08-Dec-23 11:19:14: Downloading mms1_fpi_brst_l2_dis-dist_20151016130524_v3.3.0.cdf to pydata/mms1/fpi/brst/l2/dis-dist/2015/10/16
# 08-Dec-23 11:19:37: Downloading mms1_fpi_brst_l2_dis-moms_20151016130524_v3.3.0.cdf to pydata/mms1/fpi/brst/l2/dis-moms/2015/10/16
# 08-Dec-23 11:19:39: Downloading mms1_fpi_brst_l2_des-moms_20151016130524_v3.3.0.cdf to pydata/mms1/fpi/brst/l2/des-moms/2015/10/16
# 08-Dec-23 11:19:51: Loading pydata/mms1/fpi/brst/l2/des-moms/2015/10/16/mms1_fpi_brst_l2_des-moms_20151016130524_v3.3.0.cdf
# 08-Dec-23 11:19:53: Loading pydata/mms1/fpi/brst/l2/des-dist/2015/10/16/mms1_fpi_brst_l2_des-dist_20151016130524_v3.3.0.cdf
# 08-Dec-23 11:19:55: Loading pydata/mms1/fpi/brst/l2/dis-moms/2015/10/16/mms1_fpi_brst_l2_dis-moms_20151016130524_v3.3.0.cdf
# 08-Dec-23 11:19:56: Loading pydata/mms1/fpi/brst/l2/dis-dist/2015/10/16/mms1_fpi_brst_l2_dis-dist_20151016130524_v3.3.0.cdf
# 08-Dec-23 11:19:56: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 08-Dec-23 11:19:56: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 08-Dec-23 11:19:56: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 08-Dec-23 11:19:56: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 08-Dec-23 11:19:56: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 08-Dec-23 11:19:56: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 08-Dec-23 11:19:56: Loaded variables:
# 08-Dec-23 11:19:56: Epoch
# 08-Dec-23 11:19:56: Epoch_plus_var
# 08-Dec-23 11:19:56: Epoch_minus_var
# 08-Dec-23 11:19:56: mms1_des_errorflags_brst
# 08-Dec-23 11:19:56: mms1_des_compressionloss_brst
# 08-Dec-23 11:19:56: mms1_des_steptable_parity_brst
# 08-Dec-23 11:19:56: mms1_des_startdelphi_count_brst
# 08-Dec-23 11:19:56: mms1_des_startdelphi_angle_brst
# 08-Dec-23 11:19:56: mms1_des_phi_brst
# 08-Dec-23 11:19:56: mms1_des_phi_delta_brst
# 08-Dec-23 11:19:56: mms1_des_dist_brst
# 08-Dec-23 11:19:56: mms1_des_disterr_brst
# 08-Dec-23 11:19:56: mms1_des_sector_despinp_brst
# 08-Dec-23 11:19:56: mms1_des_theta_brst
# 08-Dec-23 11:19:56: mms1_des_theta_delta_brst
# 08-Dec-23 11:19:56: mms1_des_energy_brst
# 08-Dec-23 11:19:56: mms1_des_energy_delta_brst
# 08-Dec-23 11:19:56: mms1_des_pitchangdist_lowen_brst
# 08-Dec-23 11:19:56: mms1_des_pitchangdist_miden_brst
# 08-Dec-23 11:19:56: mms1_des_pitchangdist_highen_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_px_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_mx_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_py_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_my_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_pz_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_mz_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_par_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_anti_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_perp_brst
# 08-Dec-23 11:19:56: mms1_des_energyspectr_omni_brst
# 08-Dec-23 11:19:56: mms1_des_numberdensity_brst
# 08-Dec-23 11:19:56: mms1_des_numberdensity_err_brst
# 08-Dec-23 11:19:56: mms1_des_densityextrapolation_low_brst
# 08-Dec-23 11:19:56: mms1_des_densityextrapolation_high_brst
# 08-Dec-23 11:19:56: mms1_des_bulkv_dbcs_brst
# 08-Dec-23 11:19:56: mms1_des_bulkv_spintone_dbcs_brst
# 08-Dec-23 11:19:56: mms1_des_bulkv_gse_brst
# 08-Dec-23 11:19:56: mms1_des_bulkv_spintone_gse_brst
# 08-Dec-23 11:19:56: mms1_des_bulkv_err_brst
# 08-Dec-23 11:19:56: mms1_des_prestensor_dbcs_brst
# 08-Dec-23 11:19:56: mms1_des_prestensor_gse_brst
# 08-Dec-23 11:19:56: mms1_des_prestensor_err_brst
# 08-Dec-23 11:19:56: mms1_des_temptensor_dbcs_brst
# 08-Dec-23 11:19:56: mms1_des_temptensor_gse_brst
# 08-Dec-23 11:19:56: mms1_des_temptensor_err_brst
# 08-Dec-23 11:19:56: mms1_des_heatq_dbcs_brst
# 08-Dec-23 11:19:56: mms1_des_heatq_gse_brst
# 08-Dec-23 11:19:56: mms1_des_heatq_err_brst
# 08-Dec-23 11:19:56: mms1_des_alpha_brst
# 08-Dec-23 11:19:56: mms1_des_alpha_delta_brst
# 08-Dec-23 11:19:56: mms1_des_temppara_brst
# 08-Dec-23 11:19:56: mms1_des_tempperp_brst
# 08-Dec-23 11:19:56: mms1_dis_errorflags_brst
# 08-Dec-23 11:19:56: mms1_dis_compressionloss_brst
# 08-Dec-23 11:19:56: mms1_dis_steptable_parity_brst
# 08-Dec-23 11:19:56: mms1_dis_startdelphi_count_brst
# 08-Dec-23 11:19:56: mms1_dis_startdelphi_angle_brst
# 08-Dec-23 11:19:56: mms1_dis_phi_brst
# 08-Dec-23 11:19:56: mms1_dis_phi_delta_brst
# 08-Dec-23 11:19:56: mms1_dis_dist_brst
# 08-Dec-23 11:19:56: mms1_dis_disterr_brst
# 08-Dec-23 11:19:56: mms1_dis_sector_despinp_brst
# 08-Dec-23 11:19:56: mms1_dis_theta_brst
# 08-Dec-23 11:19:56: mms1_dis_theta_delta_brst
# 08-Dec-23 11:19:56: mms1_dis_energy_brst
# 08-Dec-23 11:19:56: mms1_dis_energy_delta_brst
# 08-Dec-23 11:19:56: mms1_dis_energyspectr_px_brst
# 08-Dec-23 11:19:56: mms1_dis_energyspectr_mx_brst
# 08-Dec-23 11:19:56: mms1_dis_energyspectr_py_brst
# 08-Dec-23 11:19:56: mms1_dis_energyspectr_my_brst
# 08-Dec-23 11:19:56: mms1_dis_energyspectr_pz_brst
# 08-Dec-23 11:19:56: mms1_dis_energyspectr_mz_brst
# 08-Dec-23 11:19:56: mms1_dis_energyspectr_omni_brst
# 08-Dec-23 11:19:56: mms1_dis_spectr_bg_brst
# 08-Dec-23 11:19:56: mms1_dis_numberdensity_bg_brst
# 08-Dec-23 11:19:56: mms1_dis_numberdensity_brst
# 08-Dec-23 11:19:56: mms1_dis_numberdensity_err_brst
# 08-Dec-23 11:19:56: mms1_dis_densityextrapolation_low_brst
# 08-Dec-23 11:19:56: mms1_dis_densityextrapolation_high_brst
# 08-Dec-23 11:19:56: mms1_dis_bulkv_dbcs_brst
# 08-Dec-23 11:19:56: mms1_dis_bulkv_spintone_dbcs_brst
# 08-Dec-23 11:19:56: mms1_dis_bulkv_gse_brst
# 08-Dec-23 11:19:56: mms1_dis_bulkv_spintone_gse_brst
# 08-Dec-23 11:19:56: mms1_dis_bulkv_err_brst
# 08-Dec-23 11:19:56: mms1_dis_prestensor_dbcs_brst
# 08-Dec-23 11:19:56: mms1_dis_prestensor_gse_brst
# 08-Dec-23 11:19:56: mms1_dis_prestensor_err_brst
# 08-Dec-23 11:19:56: mms1_dis_pres_bg_brst
# 08-Dec-23 11:19:56: mms1_dis_temptensor_dbcs_brst
# 08-Dec-23 11:19:56: mms1_dis_temptensor_gse_brst
# 08-Dec-23 11:19:56: mms1_dis_temptensor_err_brst
# 08-Dec-23 11:19:56: mms1_dis_heatq_dbcs_brst
# 08-Dec-23 11:19:56: mms1_dis_heatq_gse_brst
# 08-Dec-23 11:19:56: mms1_dis_heatq_err_brst
# 08-Dec-23 11:19:56: mms1_dis_temppara_brst
# 08-Dec-23 11:19:56: mms1_dis_tempperp_brst
# 08-Dec-23 11:19:56: mms1_des_errorflags_brst_moms
# 08-Dec-23 11:19:56: mms1_des_compressionloss_brst_moms
# 08-Dec-23 11:19:56: mms1_des_errorflags_brst_dist
# 08-Dec-23 11:19:56: mms1_des_compressionloss_brst_dist
# 08-Dec-23 11:19:56: mms1_dis_errorflags_brst_moms
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_moms
# 08-Dec-23 11:19:57: mms1_dis_errorflags_brst_dist
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_dist
# 08-Dec-23 11:19:57: mms1_des_pitchangdist_avg
# 08-Dec-23 11:19:57: mms1_des_errorflags_brst_dist_flagbars_dist
# 08-Dec-23 11:19:57: mms1_des_compressionloss_brst_moms_flagbars
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_moms_flagbars
# 08-Dec-23 11:19:57: mms1_des_compressionloss_brst_dist_flagbars
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_dist_flagbars
# 08-Dec-23 11:19:57: mms1_dis_errorflags_brst_dist_flagbars_dist
# 08-Dec-23 11:19:57: mms1_des_compressionloss_brst_moms_flagbars
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_moms_flagbars
# 08-Dec-23 11:19:57: mms1_des_compressionloss_brst_dist_flagbars
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_dist_flagbars
# 08-Dec-23 11:19:57: mms1_dis_errorflags_brst_moms_flagbars_full
# 08-Dec-23 11:19:57: mms1_dis_errorflags_brst_moms_flagbars_main
# 08-Dec-23 11:19:57: mms1_dis_errorflags_brst_moms_flagbars_others
# 08-Dec-23 11:19:57: mms1_dis_errorflags_brst_moms_flagbars_mini
# 08-Dec-23 11:19:57: mms1_des_compressionloss_brst_moms_flagbars
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_moms_flagbars
# 08-Dec-23 11:19:57: mms1_des_compressionloss_brst_dist_flagbars
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_dist_flagbars
# 08-Dec-23 11:19:57: mms1_des_pitchangdist_avg
# 08-Dec-23 11:19:57: mms1_des_errorflags_brst_moms_flagbars_full
# 08-Dec-23 11:19:57: mms1_des_errorflags_brst_moms_flagbars_main
# 08-Dec-23 11:19:57: mms1_des_errorflags_brst_moms_flagbars_others
# 08-Dec-23 11:19:57: mms1_des_errorflags_brst_moms_flagbars_mini
# 08-Dec-23 11:19:57: mms1_des_compressionloss_brst_moms_flagbars
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_moms_flagbars
# 08-Dec-23 11:19:57: mms1_des_compressionloss_brst_dist_flagbars
# 08-Dec-23 11:19:57: mms1_dis_compressionloss_brst_dist_flagbars

# %% [markdown]
# ## Plot the burst mode data

# %%
tplot(['mms1_des_bulkv_gse_brst', 'mms1_dis_bulkv_gse_brst', 'mms1_des_numberdensity_brst', 'mms1_dis_numberdensity_brst'])
