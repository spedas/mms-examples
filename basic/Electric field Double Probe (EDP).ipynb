# %% [markdown]
# # Electric field Double Probe (EDP)
#
# This notebook shows how to load and plot MMS EDP data with pySPEDAS and pyTplot
#
# For information on the data, please see the Data Products Guide at:
#
# https://lasp.colorado.edu/mms/sdc/public/datasets/fields/

# %% [markdown]
# This command sets up the PySPEDAS environment when running in Google Colab.  You can skip it or comment it out if you're running this notebook in an environment that already has PySPEDAS installed.

# %%
# !pip install pyspedas

# %% [markdown]
# ## Get started
#
# To get started, import the `edp` function from the `pyspedas.projects.mms` module, and `tplot` from `pyspedas`

# %%
from pyspedas.projects.mms import edp
from pyspedas import tplot

# %% [markdown]
# ## Load the fast survey mode E-field data

# %%
edp_vars = edp(trange=['2015-10-16', '2015-10-17'])
# Out:
# SDC username (blank for public access):
# 26-Jan-22 22:53:02: Downloading mms1_edp_fast_l2_dce_20151016_v2.1.0.cdf to pydata/mms1/edp/fast/l2/dce/2015/10
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Loaded variables:
# mms1_edp_dce_gse_fast_l2
# mms1_edp_dce_dsl_fast_l2
# mms1_edp_dce_par_epar_fast_l2

# %% [markdown]
# ## Plot the E-field data in GSE coordinates

# %%
tplot('mms1_edp_dce_gse_fast_l2')

# %% [markdown]
# ## Load the burst mode E-field data

# %%
burst_vars = edp(data_rate='brst', trange=['2015-10-16/13:06', '2015-10-16/13:07'])
# Out:
# 26-Jan-22 22:53:35: Downloading mms1_edp_brst_l2_dce_20151016130524_v2.2.0.cdf to pydata/mms1/edp/brst/l2/dce/2015/10/16
# Time clip was applied to: mms1_edp_dce_gse_brst_l2
# Time clip was applied to: mms1_edp_dce_dsl_brst_l2
# Time clip was applied to: mms1_edp_dce_par_epar_brst_l2
# Loaded variables:
# mms1_edp_dce_gse_brst_l2
# mms1_edp_dce_dsl_brst_l2
# mms1_edp_dce_par_epar_brst_l2

# %% [markdown]
# ## Plot the burst mode E-field

# %%
tplot('mms1_edp_dce_gse_brst_l2')

# %% [markdown]
# ## Load the spacecraft potential data

# %%
scpot_vars = edp(datatype='scpot', trange=['2015-10-16', '2015-10-17'])
# Out:
# 26-Jan-22 22:53:50: Downloading mms1_edp_fast_l2_scpot_20151016000000_v2.7.0.cdf to pydata/mms1/edp/fast/l2/scpot/2015/10
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Loaded variables:
# mms1_edp_scpot_fast_l2
# mms1_edp_psp_fast_l2
# mms1_edp_dcv_fast_l2

# %% [markdown]
# ## Plot the spacecraft potential

# %%
tplot('mms1_edp_scpot_fast_l2')
