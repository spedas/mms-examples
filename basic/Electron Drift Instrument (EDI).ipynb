# %% [markdown]
# # Electron Drift Instrument (EDI)
#
# This notebook shows how to load and plot MMS EDI data with pySPEDAS and pyTplot
#
# For information on the data, please see the Release Notes and Data Products Guide at:
#
# https://lasp.colorado.edu/mms/sdc/public/datasets/fields/

# %% [markdown]
# This command sets up the PySPEDAS environment when running in Google Colab.  You can skip it or comment it out if you're running this notebook in an environment that already has PySPEDAS installed.

# %%
# !pip install pyspedas

# %% [markdown]
# ## Get started
#
# To get started, import the `edi` function from the `pyspedas.projects.mms` module, and `tplot` from `pyspedas`

# %%
from pyspedas.projects.mms import edi
from pyspedas import tplot

# %% [markdown]
# ## Load the survey mode electron drift data

# %%
edi_vars = edi(trange=['2015-12-23', '2015-12-24'])
# Out:
# SDC username (blank for public access):
# 26-Jan-22 22:55:15: Downloading mms1_edi_srvy_l2_efield_20151223_v1.6.2.cdf to pydata/mms1/edi/srvy/l2/efield/2015/12
# Loaded variables:
# mms1_edi_vdrift_dsl_srvy_l2
# mms1_edi_vdrift_gse_srvy_l2
# mms1_edi_vdrift_gsm_srvy_l2
# mms1_edi_e_dsl_srvy_l2
# mms1_edi_e_gse_srvy_l2
# mms1_edi_e_gsm_srvy_l2
# mms1_edi_tri_weight_srvy_l2

# %% [markdown]
# ## Plot the ExB drift velocity in GSE coordinates

# %%
tplot('mms1_edi_vdrift_gse_srvy_l2')
