# %% [markdown]
# # MMS Orbit Plots
#
# This notebook shows how to create plots of the MMS orbits

# %%
from pyspedas.mms.mms_orbit_plot import mms_orbit_plot

# %% [markdown]
# ## Create the plot for all 4 spacecraft for the entire day of Oct 16, 2015 in GSE coordinates

# %%
mms_orbit_plot(trange=['2015-10-16', '2015-10-17'])
# Out:
# 29-Oct-19 13:05:06: Loading /Volumes/data/data/mms/mms1/mec/srvy/l2/ephts04d/2015/10/mms1_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:05:06: Loading /Volumes/data/data/mms/mms2/mec/srvy/l2/ephts04d/2015/10/mms2_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:05:06: Loading /Volumes/data/data/mms/mms3/mec/srvy/l2/ephts04d/2015/10/mms3_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:05:06: Loading /Volumes/data/data/mms/mms4/mec/srvy/l2/ephts04d/2015/10/mms4_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:05:07: /Users/eric/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
#
# 29-Oct-19 13:05:07: /Users/eric/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
#
# 29-Oct-19 13:05:07: /Users/eric/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2366: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return list(data) if isinstance(data, collections.MappingView) else data
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Loaded variables:
# mms1_mec_r_gse
# mms1_mec_r_gse2000
# mms2_mec_r_gse
# mms2_mec_r_gse2000
# mms3_mec_r_gse
# mms3_mec_r_gse2000
# mms4_mec_r_gse
# mms4_mec_r_gse2000

# %% [markdown]
# ## Change the coordinate system to SM

# %%
mms_orbit_plot(trange=['2015-10-16', '2015-10-17'], coord='sm')
# Out:
# 29-Oct-19 13:06:56: Loading /Volumes/data/data/mms/mms1/mec/srvy/l2/ephts04d/2015/10/mms1_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:06:56: Loading /Volumes/data/data/mms/mms2/mec/srvy/l2/ephts04d/2015/10/mms2_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:06:56: Loading /Volumes/data/data/mms/mms3/mec/srvy/l2/ephts04d/2015/10/mms3_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:06:56: Loading /Volumes/data/data/mms/mms4/mec/srvy/l2/ephts04d/2015/10/mms4_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:06:59: /Users/eric/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Loaded variables:
# mms1_mec_r_sm
# mms2_mec_r_sm
# mms3_mec_r_sm
# mms4_mec_r_sm

# %% [markdown]
# ## Change the plane to XZ

# %%
mms_orbit_plot(trange=['2015-10-16', '2015-10-17'], plane='xz')
# Out:
# 29-Oct-19 13:08:32: Loading /Volumes/data/data/mms/mms1/mec/srvy/l2/ephts04d/2015/10/mms1_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:08:32: Loading /Volumes/data/data/mms/mms2/mec/srvy/l2/ephts04d/2015/10/mms2_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:08:32: Loading /Volumes/data/data/mms/mms3/mec/srvy/l2/ephts04d/2015/10/mms3_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:08:32: Loading /Volumes/data/data/mms/mms4/mec/srvy/l2/ephts04d/2015/10/mms4_mec_srvy_l2_ephts04d_20151016_v2.0.0.cdf
# 29-Oct-19 13:08:36: /Users/eric/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Time clip returns full data set.
# Loaded variables:
# mms1_mec_r_gse
# mms1_mec_r_gse2000
# mms2_mec_r_gse
# mms2_mec_r_gse2000
# mms3_mec_r_gse
# mms3_mec_r_gse2000
# mms4_mec_r_gse
# mms4_mec_r_gse2000
