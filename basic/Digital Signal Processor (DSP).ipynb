# %% [markdown]
# # Digital Signal Processor (DSP)
#
# This notebook shows how to load and plot MMS DSP data with pySPEDAS and pyTplot
#
# For information on the data, please see the Data Products Guide at:
#
# https://lasp.colorado.edu/mms/sdc/public/datasets/fields/

# %% [markdown]
# This command sets up the PySPEDAS environment when running in Google Colab.  You can skip it or comment it out if you're running this notebook in an environment that already has PySPEDAS installed.

# %%
# !pip install pyspedas

# %% [markdown]
# ## Get started
#
# To get started, import the `dsp` function from the `pyspedas.projects.mms` module, and `tplot` from `pyspedas`

# %%
from pyspedas.projects.mms import dsp
from pyspedas import tplot

# %% [markdown]
# ## Load the electric spectral density

# %%
epsd_vars = dsp(data_rate='fast', probe=1, datatype='epsd', level='l2')
# Out:
# SDC username (blank for public access):
# 26-Jan-22 22:16:36: Downloading mms1_dsp_fast_l2_epsd_20151016_v0.6.4.cdf to pydata/mms1/dsp/fast/l2/epsd/2015/10
# Loaded variables:
# mms1_dsp_epsd_x
# mms1_dsp_epsd_y
# mms1_dsp_epsd_z
# mms1_dsp_epsd_omni

# %% [markdown]
# ## Plot the electric spectral density

# %%
tplot(['mms1_dsp_epsd_omni'])

# %% [markdown]
# ## Load the magnetic spectral density

# %%
bpsd_vars = dsp(data_rate='fast', probe=1, datatype='bpsd', level='l2')
# Out:
# 26-Jan-22 22:16:58: Downloading mms1_dsp_fast_l2_bpsd_20151016_v2.1.1.cdf to pydata/mms1/dsp/fast/l2/bpsd/2015/10
# Loaded variables:
# mms1_dsp_bpsd_scm1_fast_l2
# mms1_dsp_bpsd_scm2_fast_l2
# mms1_dsp_bpsd_scm3_fast_l2
# mms1_dsp_bpsd_omni_fast_l2

# %% [markdown]
# ## Plot the omni-directional SCM spectral density

# %%
tplot('mms1_dsp_bpsd_omni_fast_l2')
